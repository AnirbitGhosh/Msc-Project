# %%
import os
import math
from abc import abstractmethod

from PIL import Image
import requests
import numpy as np
import time
import torch
import torch.nn as nn
import torch.nn.functional as F
from torchvision import datasets, transforms
from tqdm import tqdm
import matplotlib.pyplot as plt
from torchvision import transforms, datasets
from torch.utils.data import Dataset, DataLoader, ConcatDataset
import pickle
import pandas as pd
from PIL import Image
import cv2 as cv
from skimage import io, img_as_float
from skimage.filters import threshold_sauvola

# %matplotlib inline

# %%
VOL_DIR = "/vol/bitbucket/ag323/diss_ag"
device = "cuda" if torch.cuda.is_available() else "cpu"

# %% [markdown]
# ## Unet and Gaussian Diffusion

# %%
def timestep_embedding(timesteps, dim, max_period=1000):
    half = dim // 2
    freqs = torch.exp(
        -math.log(max_period) * torch.arange(start=0, end=half, dtype=torch.float32) / half
    ).to(device=timesteps.device)
    args = timesteps[:, None].float() * freqs[None]
    embedding = torch.cat([torch.cos(args), torch.sin(args)], dim=-1)
    if dim % 2:
        embedding = torch.cat([embedding, torch.zeros_like(embedding[:, :1])], dim=-1)
    return embedding

class TimestepBlock(nn.Module):
    @abstractmethod
    def forward(self, x, emb):
        """
        Apply the module to `x` given `emb` timestep embeddings.
        """

class TimestepEmbedSequential(nn.Sequential, TimestepBlock):
    """
    A sequential module that passes timestep embeddings to the children that
    support it as an extra input.
    """
    def forward(self, x, t_emb, c_emb, mask):
        for layer in self:
            if(isinstance(layer, TimestepBlock)):
                x = layer(x, t_emb, c_emb, mask)
            else:
                x = layer(x)
            return x

def norm_layer(channels):
    return nn.GroupNorm(32, channels)

class ResidualBlock(TimestepBlock):
    def __init__(self, in_channels, out_channels, time_channels, cond_channels, dropout):
        super().__init__()
        self.conv1 = nn.Sequential(
            norm_layer(in_channels),
            nn.SiLU(),
            nn.Conv2d(in_channels, out_channels, kernel_size=3, padding=1)
        )
        
        self.time_emb = nn.Sequential(
            nn.SiLU(),
            nn.Linear(time_channels, out_channels)
        )
        
        self.cond_conv = nn.Sequential(
            nn.Conv2d(cond_channels, out_channels, kernel_size=3, padding=1),
            nn.SiLU()
        )
        
        self.conv2 = nn.Sequential(
            norm_layer(out_channels),
            nn.SiLU(),
            nn.Dropout(p=dropout),
            nn.Conv2d(out_channels, out_channels, kernel_size=3, padding=1)
        )
        
        if in_channels != out_channels:
            self.shortcut = nn.Conv2d(in_channels, out_channels, kernel_size=1)
        else:
            self.shortcut = nn.Identity()
    
    def forward(self, x, t, cond_img, mask):
        h = self.conv1(x)
        emb_t = self.time_emb(t)
        emb_cond = self.cond_conv(cond_img) * mask[:, None, None, None]
        h += (emb_t[:, :, None, None] + emb_cond)
        h = self.conv2(h)
        
        return h + self.shortcut(x)
    
class AttentionBlock(nn.Module):
    def __init__(self, channels, num_heads=1):
        super().__init__()
        self.num_heads = num_heads
        assert channels % num_heads == 0
        
        self.norm = norm_layer(channels)
        self.qkv = nn.Conv2d(channels, channels * 3, kernel_size=1, bias=False)
        self.proj = nn.Conv2d(channels, channels, kernel_size=1)
        
    def forward(self, x):
        B, C, H, W = x.shape
        qkv = self.qkv(self.norm(x))
        q, k, v = qkv.reshape(B *  self.num_heads, -1, H * W).chunk(3, dim=1)
        scale = 1. / math.sqrt(math.sqrt(C // self.num_heads))
        attn = torch.einsum("bct,bcs->bts", q * scale, k * scale)
        attn = attn.softmax(dim=-1)
        h = torch.einsum("bts,bcs->bct", attn, v)
        h = h.reshape(B, -1, H, W)
        h = self.proj(h)
        return h + x
    
class UpSample(nn.Module):
    def __init__(self, channels, use_conv):
        super().__init__()
        self.use_conv = use_conv
        if use_conv:
            self.conv = nn.Conv2d(channels, channels, kernel_size=3, padding=1)
    
    def forward(self, x):
        x = F.interpolate(x, scale_factor=2, mode="nearest")
        if self.use_conv:
            x = self.conv(x)
        return x

class DownSample(nn.Module):
    def __init__(self, channels, use_conv):
        super().__init__()
        self.use_conv = use_conv
        if use_conv:
            self.op = nn.Conv2d(channels, channels, kernel_size=3, padding=1, stride=2)
        else:
            self.op = nn.AvgPool2d(stride=2)
    
    def forward(self, x):
        return self.op(x)
    
class Unet(nn.Module):
    def __init__(self, 
                 in_channels=2,
                 cond_channels=1,
                 model_channels=128,
                 out_channels=2,
                 num_res_blocks=2, 
                 attention_resolutions=(8, 16),
                 dropout=0,
                 channel_mult=(1, 2, 2, 2),
                 conv_resample=True,
                 num_heads=4):
        super().__init__()
        self.in_channels = in_channels
        self.cond_channels = cond_channels
        self.model_channels = model_channels
        self.out_channels = out_channels
        self.num_res_blocks = num_res_blocks
        self.attention_resolutions = attention_resolutions,
        self.dropout = dropout
        self.channel_mult = channel_mult,
        self.conv_resample = conv_resample
        self.num_heads = num_heads
        
        # time embedding
        time_emb_dim = model_channels * 4
        self.time_emb = nn.Sequential(
            nn.Linear(model_channels, time_emb_dim),
            nn.SiLU(),
            nn.Linear(time_emb_dim, time_emb_dim)
        )
        
        # down blocks
        self.down_blocks = nn.ModuleList([
            TimestepEmbedSequential(nn.Conv2d(in_channels, model_channels, kernel_size=3, padding=1))
        ])
        down_block_channels = [model_channels]
        ch = model_channels
        ds = 1
        for level, mult in enumerate(channel_mult):
            for _ in range(num_res_blocks):
                layers = [ResidualBlock(ch, model_channels * mult, time_emb_dim, cond_channels, dropout)]
                ch = model_channels * mult
                if ds in attention_resolutions:
                    layers.append(AttentionBlock(ch, num_heads))
                self.down_blocks.append(TimestepEmbedSequential(*layers))
                down_block_channels.append(ch)
            if level != len(channel_mult) - 1:
                self.down_blocks.append(TimestepEmbedSequential(DownSample(ch, conv_resample)))
                down_block_channels.append(ch)
                ds *= 2
        
        # middle blocks
        self.middle_blocks = TimestepEmbedSequential(
            ResidualBlock(ch, ch, time_emb_dim, cond_channels, dropout),
            AttentionBlock(ch, num_heads),
            ResidualBlock(ch, ch, time_emb_dim, cond_channels, dropout)
        )
        
        # up blocks
        self.up_blocks = nn.ModuleList([])
        for level, mult in enumerate(channel_mult[::-1]):
            for i in range(num_res_blocks + 1):
                layers = [
                    ResidualBlock(ch + down_block_channels.pop(), model_channels * mult, time_emb_dim, cond_channels, dropout)]
                ch = model_channels * mult
                if ds in attention_resolutions:
                    layers.append(AttentionBlock(ch, num_heads))
                if level != len(channel_mult) - 1 and i == num_res_blocks:
                    layers.append(UpSample(ch, conv_resample))
                    ds //= 2
                self.up_blocks.append(TimestepEmbedSequential(*layers))
                
        self.out = nn.Sequential(
            norm_layer(ch),
            nn.SiLU(),
            nn.Conv2d(ch, out_channels, kernel_size=3, padding=1)
        )
    
    def forward(self, x, timesteps, cond_img, mask):
        """
        Apply the model to an input batch.
        :param x: an [N x C x H x W] Tensor of inputs.
        :param timesteps: a 1-D batch of timesteps.
        :param cond_img: a [N x cond_C x H x W] Tensor of conditional images.
        :param mask: a 1-D batch of conditioned/unconditioned.
        :return: an [N x C x ...] Tensor of outputs.
        """
        hs = []
        # time step embedding
        t_emb = self.time_emb(timestep_embedding(timesteps, dim=self.model_channels))
        
        # down step
        h = x
        for module in self.down_blocks:
            if cond_img.shape[2:] != h.shape[2:]:
                cond_img = F.interpolate(cond_img, size=h.shape[2:], mode='nearest')
            h = module(h, t_emb, cond_img, mask)
            hs.append(h)
        # mid stage
        if cond_img.shape[2:] != h.shape[2:]:
            cond_img = F.interpolate(cond_img, size=h.shape[2:], mode='nearest')
        h = self.middle_blocks(h, t_emb, cond_img, mask)

        mid_block_features = h
        
        # up stage
        for module in self.up_blocks:
            h_skip = hs.pop()
            
            if h.shape[2:] != h_skip.shape[2:]:
                h = F.interpolate(h, size=h_skip.shape[2:], mode='nearest')

            if cond_img.shape[2:] != h.shape[2:]:
                cond_img = F.interpolate(cond_img, size=h.shape[2:], mode='nearest')

            cat_in = torch.cat([h, h_skip], dim=1)
            h = module(cat_in, t_emb, cond_img, mask)
        
        return self.out(h), mid_block_features

# %%
# beta schedule
def linear_beta_schedule(timesteps):
    scale = 1000 / timesteps
    beta_start = scale * 0.0001
    beta_end = scale * 0.02
    return torch.linspace(beta_start, beta_end, timesteps, dtype=torch.float64)

def sigmoid_beta_schedule(timesteps):
    betas = torch.linspace(-6, 6, timesteps)
    betas = torch.sigmoid(betas) / (betas.max() - betas.min()) * (0.02 - betas.min()) / 10
    return betas

def cosine_beta_schedule(timesteps, s=0.008):
    steps = timesteps + 1
    x = torch.linspace(0, timesteps, steps, dtype=torch.float64)
    alphas_cumprod = torch.cos(((x / timesteps) + s) / (1 + s) * math.pi * 0.5) ** 2
    alphas_cumprod = alphas_cumprod / alphas_cumprod[0]
    betas = 1 - (alphas_cumprod[1:] / alphas_cumprod[:-1])
    return torch.clip(betas, 0, 0.999)

# %%
class GaussianDiffusion:
    def __init__(
        self,
        timesteps=1000,
        beta_schedule='linear',
    ):
        self.timesteps = timesteps
        
        if beta_schedule == 'linear':
            betas = linear_beta_schedule(timesteps)
        elif beta_schedule == 'cosine':
            betas = cosine_beta_schedule(timesteps)
        elif beta_schedule == 'sigmoid':
            betas = sigmoid_beta_schedule(timesteps)
        else:
            raise ValueError(f'Unknown beta schedule {beta_schedule}')
        
        self.betas = betas
        
        self.alphas = 1. - self.betas
        self.alphas_cumprod = torch.cumprod(self.alphas, axis=0)
        self.alphas_cumprod_prev = F.pad(self.alphas_cumprod[:-1], (1, 0), value=1.)
        
        # calculations for diffusion q(x_t | x_{t-1}) and others
        self.sqrt_alphas_cumprod = torch.sqrt(self.alphas_cumprod)
        self.sqrt_one_minus_alphas_cumprod = torch.sqrt(1.0 - self.alphas_cumprod)
        self.log_one_minus_alphas_cumprod = torch.log(1.0 - self.alphas_cumprod)
        self.sqrt_recip_alphas_cumprod = torch.sqrt(1.0 / self.alphas_cumprod)
        self.sqrt_recipm1_alphas_cumprod = torch.sqrt(1.0 / self.alphas_cumprod - 1)
        
        # calculations for posterior q(x_{t-1} | x_t, x_0)
        self.posterior_variance = (
            self.betas * (1.0 - self.alphas_cumprod_prev) / (1.0 - self.alphas_cumprod)
        )
        self.posterior_log_variance_clipped = torch.log(
            torch.cat([self.posterior_variance[1:2], self.posterior_variance[1:]])
        )
        
        self.posterior_mean_coef1 = (
            self.betas * torch.sqrt(self.alphas_cumprod_prev) / (1.0 - self.alphas_cumprod)
        )
        self.posterior_mean_coef2 = (
            (1.0 - self.alphas_cumprod_prev) * torch.sqrt(self.alphas) / (1.0 - self.alphas_cumprod)
        )
    
    # get the param of given timestep t
    def _extract(self, a, t, x_shape):
        batch_size = t.shape[0]
        out = a.to(t.device).gather(0, t).float()
        out = out.reshape(batch_size, *((1,) * (len(x_shape) - 1)))
        return out
    
    # forward diffusion : q(x_t | x_0)
    def q_sample(self, x_start, t, noise=None):
        if noise is None:
            noise = torch.randn_like(x_start)
        
        sqrt_alphas_cumprod_t = self._extract(self.sqrt_alphas_cumprod, t, x_start.shape)
        sqrt_one_minus_alphas_cumprod_t = self._extract(self.sqrt_one_minus_alphas_cumprod, t, x_start.shape)
        
        return sqrt_alphas_cumprod_t * x_start + sqrt_one_minus_alphas_cumprod_t * noise
    
    # mean and variance of q(x_t | x_0)
    def q_mean_variance(self, x_start, t):
        mean = self._extract(self.sqrt_alphas_cumprod, t, x_start.shape) * x_start
        variance = self._extract(1.0 - self.alphas_cumprod, t, x_start.shape)
        log_variance = self._extract(self.log_one_minus_alphas_cumprod, t, x_start.shape)
        return mean, variance, log_variance
    
    # mean and variance of diffusion posterior: q(x_{t-1} | x_t, x_0)
    def q_posterior_mean_variance(self, x_start, x_t, t):
        posterior_mean = (
            self._extract(self.posterior_mean_coef1, t, x_t.shape) * x_start + self._extract(self.posterior_mean_coef2, t, x_t.shape) * x_t
        )
        posterior_variance = self._extract(self.posterior_variance, t, x_t.shape)
        posterior_log_variance_clipped = self._extract(self.posterior_log_variance_clipped, t, x_t.shape)
        return posterior_mean, posterior_variance, posterior_log_variance_clipped
    
    # compute x_0 from x_t and pred noise: reverse of q_sample
    def predict_start_from_noise(self, x_t, t, noise):
        return (
            self._extract(self.sqrt_recip_alphas_cumprod, t, x_t.shape) * x_t - self._extract(self.sqrt_recipm1_alphas_cumprod, t, x_t.shape) * noise
        )
    
    # compute predicted mean and variance of p(x_{t-1} | x_t) 
    def p_mean_variance(self, model, x_t, t, cond_img, w, clip_denoised=True):
        device = next(model.parameters()).device
        batch_size = x_t.shape[0]
        
        # noise prediction from model
        pred_noise_cond, mid_block_features = model(x_t, t, cond_img, torch.ones(batch_size).int().to(device))
        pred_noise_uncond, mid_block_features = model(x_t, t, cond_img, torch.zeros(batch_size).int().to(device))
        pred_noise = (1 + w) * pred_noise_cond - w * pred_noise_uncond
        
        # get predicted x_0
        x_recon = self.predict_start_from_noise(x_t, t, pred_noise)
        if clip_denoised:
            x_recon = torch.clamp(x_recon, min=-1., max=1.)
        model_mean, posterior_variance, posterior_log_variance = self.q_posterior_mean_variance(x_recon, x_t, t)
        
        return model_mean, posterior_variance, posterior_log_variance
    
    # denoise step: sample x_{t-1} from x_t and pred noise
    @torch.no_grad()
    def p_sample(self, model, x_t, t, cond_img, w, clip_denoised=True):
        # pred mean and variance
        model_mean, _, model_log_variance = self.p_mean_variance(model, x_t, t, cond_img, w, clip_denoised=clip_denoised)
        
        noise = torch.randn_like(x_t)
        # no noise when t = 0 
        nonzero_mask = ((t != 0).float().view(-1, *([1] * (len(x_t.shape) - 1))))
        # compute x_{t-1}
        pred_img = model_mean + nonzero_mask * (0.5 * model_log_variance).exp() * noise
        return pred_img
    
    # denoise : reverse diffusion
    @torch.no_grad()
    def p_sample_loop(self, model, shape, cond_img, w=2, clip_denoised=True):
        batch_size = shape[0]
        device = next(model.parameters()).device
        
        # start from pure noise
        img = torch.randn(shape, device=device)
        imgs = []
        for i in tqdm(reversed(range(0, self.timesteps)), desc='sampling loop time step', total=self.timesteps):
            img = self.p_sample(model, img, torch.full((batch_size,), i, device=device, dtype=torch.long), cond_img, w, clip_denoised)
            imgs.append(img.cpu().numpy())
        return imgs
    
    # sample new images
    @torch.no_grad
    def sample(self, model, image_size, cond_img, batch_size=8, channels=3, w=2, clip_denoised=True):
        return self.p_sample_loop(model, (batch_size, channels, image_size, image_size), cond_img, w, clip_denoised)
    
    # use ddim to sample
    @torch.no_grad()
    def ddim_sample(
        self,
        model,
        image_size,
        cond_img,
        batch_size=8,
        channels=3,
        ddim_timesteps=50,
        w=2,
        ddim_discr_method="uniform",
        ddim_eta=0.0,
        clip_denoised=True):
        
        # make ddim timestep sequence
        if ddim_discr_method == 'uniform':
            c = self.timesteps // ddim_timesteps
            ddim_timestep_seq = np.asarray(list(range(0, self.timesteps, c)))
        elif ddim_discr_method == 'quad':
            ddim_timestep_seq = (
                (np.linspace(0, np.sqrt(self.timesteps * .8), ddim_timesteps)) ** 2
            ).astype(int)
        else:
            raise NotImplementedError(f'There is no ddim discretization method called "{ddim_discr_method}"')
        # add one to get the final alpha values right (the ones from first scale to data during sampling)
        ddim_timestep_seq = ddim_timestep_seq + 1
        # previous sequence
        ddim_timestep_prev_seq = np.append(np.array([0]), ddim_timestep_seq[:-1])
        
        device = next(model.parameters()).device
        
        # start from pure noise (for each example in the batch)
        sample_img = torch.randn((batch_size, channels, image_size, image_size), device=device)
        seq_img = [sample_img.cpu().numpy()]   
        
        for i in tqdm(reversed(range(0, ddim_timesteps)), desc='sampling loop time step', total=ddim_timesteps):
            t = torch.full((batch_size,), ddim_timestep_seq[i], device=device, dtype=torch.long)
            prev_t = torch.full((batch_size,), ddim_timestep_prev_seq[i], device=device, dtype=torch.long)
            
            # 1. get current and previous alpha_cumprod
            alpha_cumprod_t = self._extract(self.alphas_cumprod, t, sample_img.shape)
            alpha_cumprod_t_prev = self._extract(self.alphas_cumprod, prev_t, sample_img.shape)
    
            # 2. predict noise using model
            pred_noise_cond, mid_block_features = model(sample_img, t, cond_img, torch.ones(batch_size).int().cuda())
            pred_noise_uncond, mid_block_features = model(sample_img, t, cond_img, torch.zeros(batch_size).int().cuda())
            pred_noise = (1+w)*pred_noise_cond - w*pred_noise_uncond
            
            # 3. get the predicted x_0
            pred_x0 = (sample_img - torch.sqrt((1. - alpha_cumprod_t)) * pred_noise) / torch.sqrt(alpha_cumprod_t)
            if clip_denoised:
                pred_x0 = torch.clamp(pred_x0, min=-1., max=1.)
            
            # 4. compute variance: "sigma_t(η)" -> see formula (16)
            # σ_t = sqrt((1 − α_t−1)/(1 − α_t)) * sqrt(1 − α_t/α_t−1)
            sigmas_t = ddim_eta * torch.sqrt(
                (1 - alpha_cumprod_t_prev) / (1 - alpha_cumprod_t) * (1 - alpha_cumprod_t / alpha_cumprod_t_prev))
            
            # 5. compute "direction pointing to x_t" of formula (12)
            pred_dir_xt = torch.sqrt(1 - alpha_cumprod_t_prev - sigmas_t**2) * pred_noise
            
            # 6. compute x_{t-1} of formula (12)
            x_prev = torch.sqrt(alpha_cumprod_t_prev) * pred_x0 + pred_dir_xt + sigmas_t * torch.randn_like(sample_img)

            sample_img = x_prev

        return sample_img.cpu().numpy()
    
    # compute train losses
    def train_losses(self, model, x_start, t, cond_img, mask_c):
        # generate random noise
        noise = torch.randn_like(x_start)
        # get x_t
        x_noisy = self.q_sample(x_start, t, noise=noise)
        predicted_noise, mid_block_features = model(x_noisy, t, cond_img, mask_c)
        loss = F.mse_loss(noise, predicted_noise)
        return loss, predicted_noise, mid_block_features

# %% [markdown]
# ## Dataset

# %%
class ConditionalImageDataset(Dataset):
    def __init__(self, data_dir, transform=None, conditional_offset=5):
        self.data_dir = data_dir
        self.transform = transform
        self.conditional_offset = conditional_offset
        self.regression_csv_path = os.path.join(data_dir, "regression_params.csv")
        self.cond_images = []
        self.target_images = []
        self.reg_data = None
        self._load_data()

    def _load_data(self):
        files = sorted([os.path.join(self.data_dir, f) for f in os.listdir(self.data_dir) if f.endswith('.mpy')])
        for file in files:
            with open(file, 'rb') as f:
                images = pickle.load(f)
                if isinstance(images, list):
                    images = np.array(images)
                    
                for img_idx in range(len(images) - self.conditional_offset):
                    self.cond_images.append(images[img_idx])
                    self.target_images.append(images[img_idx + self.conditional_offset])
                    
        headers = ["p_h", "a", "c_1", "c_2", "c_x", "c_y"]
        self.reg_data = pd.read_csv(self.regression_csv_path, names=headers, index_col=0)

    def __len__(self):
        return len(self.cond_images)

    def __getitem__(self, idx):
        cond_image = self.cond_images[idx]
        image = self.target_images[idx]
        reg_params = self.reg_data.loc[idx // 15].to_numpy()

        if self.transform:
            image = self.transform(image)
            cond_image = self.transform(cond_image)

        return image, cond_image, reg_params

# %% [markdown]
# ## Regression Model

# %%
# Define the MLP regression model
class MLPRegressor(nn.Module):
    def __init__(self, input_channels, feature_size, hidden_sizes, output_size):
        super(MLPRegressor, self).__init__()
        input_size = input_channels * feature_size * feature_size
        self.fc_layers = nn.ModuleList()
        
        # Define the MLP layers
        in_size = input_size
        for hidden_size in hidden_sizes:
            self.fc_layers.append(nn.Linear(in_size, hidden_size))
            self.fc_layers.append(nn.ReLU())
            self.fc_layers.append(nn.Dropout(p=0.5))  # Adding dropout for regularization
            in_size = hidden_size
        self.fc_layers.append(nn.Linear(in_size, output_size))

    def forward(self, x):
        # Flatten the input
        x = x.view(x.size(0), -1)
        
        # Forward pass through the layers
        for layer in self.fc_layers:
            x = layer(x)
        
        return x

# %%
# Parameters
input_channels = 192  # Number of input channels
feature_size = 16     # Feature size (16x16)
hidden_sizes = [2048, 1024, 512, 256]  # Example hidden layer sizes
output_size = 6  # Number of predicted values

# Instantiate the model, loss function, and optimizer
reg_model = MLPRegressor(input_channels, feature_size, hidden_sizes, output_size)
reg_model.to(device)

# Define the loss function and optimizer
reg_criterion = nn.MSELoss()
reg_optimizer = torch.optim.Adam(reg_model.parameters(), lr=0.001)

# %%
def train_regressor(model, train_data, optimizer, criterion, epochs=10):
    for epoch in range(epochs):
        model.train()
        optimizer.zero_grad()

        input_features, reg_params = train_data
        
        output = model(input_features)
        loss = criterion(output, reg_params)

        print(f'Regression Training - Epoch {epoch+1}/{epochs}, Loss: {loss.item()}')
        return loss

# %% [markdown]
# ## Regression Guided Diffusion Training

# %%
batch_size = 32
timesteps = 500

aug_transform = transforms.Compose([
    transforms.ToTensor(),  # Convert to tensor
    transforms.Resize(64),
    transforms.RandomRotation(degrees=15, fill=0),
    transforms.RandomAffine(degrees=0, translate=(0.1, 0.1), fill=0),
    transforms.RandomHorizontalFlip(p=0.5),
    transforms.RandomVerticalFlip(p=0.5),
])

id_transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Resize(64)
])

DATA_DIR = os.path.join(VOL_DIR, "data/simulated_bin_frames_2")
RESULT_DIR = os.path.join(VOL_DIR, "results/")
CKPT_DIR = os.path.join(VOL_DIR, "results/ckpts") 

# Dataset
base_dataset = ConditionalImageDataset(DATA_DIR, transform=id_transform)
aug_dataset = ConditionalImageDataset(DATA_DIR, transform=aug_transform)

# dataset = ConcatDataset([base_dataset, aug_dataset])
dataset = base_dataset

# Split dataset into training and testing
train_size = int(0.9 * len(dataset))
test_size = len(dataset) - train_size
train_dataset, test_dataset = torch.utils.data.random_split(dataset, [train_size, test_size])

# Create DataLoader
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=batch_size, shuffle=True)

device = "cuda" if torch.cuda.is_available() else "cpu"
diff_model = Unet(
    in_channels=1,
    cond_channels=1,
    model_channels=96,
    out_channels=1,
    channel_mult=(1, 2, 2),
    attention_resolutions=[],
)
diff_model.to(device)
# Out:
# Unet(
#   (time_emb): Sequential(
#     (0): Linear(in_features=96, out_features=384, bias=True)
#     (1): SiLU()
#     (2): Linear(in_features=384, out_features=384, bias=True)
#   )
#   (down_blocks): ModuleList(
#     (0): TimestepEmbedSequential(
#       (0): Conv2d(1, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (1-2): 2 x TimestepEmbedSequential(
#       (0): ResidualBlock(
#         (conv1): Sequential(
#           (0): GroupNorm(32, 96, eps=1e-05, affine=True)
#           (1): SiLU()
#           (2): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#         (time_emb): Sequential(
#           (0): SiLU()
#           (1): Linear(in_features=384, out_features=96, bias=True)
#         )
#         (cond_conv): Sequential(
#           (0): Conv2d(1, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): SiLU()
#         )
#         (conv2): Sequential(
#           (0): GroupNorm(32, 96, eps=1e-05, affine=True)
#           (1): SiLU()
#           (2): Dropout(p=0, inplace=False)
#           (3): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#         (shortcut): Identity()
#       )
#     )
#     (3): TimestepEmbedSequential(
#       (0): DownSample(
#         (op): Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       )
#     )
#     (4): TimestepEmbedSequential(
#       (0): ResidualBlock(
#         (conv1): Sequential(
#           (0): GroupNorm(32, 96, eps=1e-05, affine=True)
#           (1): SiLU()
#           (2): Conv2d(96, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#         (time_emb): Sequential(
#           (0): SiLU()
#           (1): Linear(in_features=384, out_features=192, bias=True)
#         )
#         (cond_conv): Sequential(
#           (0): Conv2d(1, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): SiLU()
#         )
#         (conv2): Sequential(
#           (0): GroupNorm(32, 192, eps=1e-05, affine=True)
#           (1): SiLU()
#           (2): Dropout(p=0, inplace=False)
#           (3): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#         (shortcut): Conv2d(96, 192, kernel_size=(1, 1), stride=(1, 1))
#       )
#     )
#     (5): TimestepEmbedSequential(
#       (0): ResidualBlock(
#         (conv1): Sequential(
#           (0): GroupNorm(32, 192, eps=1e-05, affine=True)
#           (1): SiLU()
#           (2): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#         (time_emb): Sequential(
#           (0): SiLU()
#           (1): Linear(in_features=384, out_features=192, bias=True)
#         )
#         (cond_conv): Sequential(
#           (0): Conv2d(1, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): SiLU()
#         )
#         (conv2): Sequential(
#           (0): GroupNorm(32, 192, eps=1e-05, affine=True)
#           (1): SiLU()
#           (2): Dropout(p=0, inplace=False)
#           (3): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#         (shortcut): Identity()
#       )
#     )
#     (6): TimestepEmbedSequential(
#       (0): DownSample(
#         (op): Conv2d(192, 192, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       )
#     )
#     (7-8): 2 x TimestepEmbedSequential(
#       (0): ResidualBlock(
#         (conv1): Sequential(
#           (0): GroupNorm(32, 192, eps=1e-05, affine=True)
#           (1): SiLU()
#           (2): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#         (time_emb): Sequential(
#           (0): SiLU()
#           (1): Linear(in_features=384, out_features=192, bias=True)
#         )
#         (cond_conv): Sequential(
#           (0): Conv2d(1, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): SiLU()
#         )
#         (conv2): Sequential(
#           (0): GroupNorm(32, 192, eps=1e-05, affine=True)
#           (1): SiLU()
#           (2): Dropout(p=0, inplace=False)
#           (3): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#         (shortcut): Identity()
#       )
#     )
#   )
#   (middle_blocks): TimestepEmbedSequential(
#     (0): ResidualBlock(
#       (conv1): Sequential(
#         (0): GroupNorm(32, 192, eps=1e-05, affine=True)
#         (1): SiLU()
#         (2): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#       (time_emb): Sequential(
#         (0): SiLU()
#         (1): Linear(in_features=384, out_features=192, bias=True)
#       )
#       (cond_conv): Sequential(
#         (0): Conv2d(1, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): SiLU()
#       )
#       (conv2): Sequential(
#         (0): GroupNorm(32, 192, eps=1e-05, affine=True)
#         (1): SiLU()
#         (2): Dropout(p=0, inplace=False)
#         (3): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#       (shortcut): Identity()
#     )
#     (1): AttentionBlock(
#       (norm): GroupNorm(32, 192, eps=1e-05, affine=True)
#       (qkv): Conv2d(192, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (proj): Conv2d(192, 192, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (2): ResidualBlock(
#       (conv1): Sequential(
#         (0): GroupNorm(32, 192, eps=1e-05, affine=True)
#         (1): SiLU()
#         (2): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#       (time_emb): Sequential(
#         (0): SiLU()
#         (1): Linear(in_features=384, out_features=192, bias=True)
#       )
#       (cond_conv): Sequential(
#         (0): Conv2d(1, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): SiLU()
#       )
#       (conv2): Sequential(
#         (0): GroupNorm(32, 192, eps=1e-05, affine=True)
#         (1): SiLU()
#         (2): Dropout(p=0, inplace=False)
#         (3): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#       (shortcut): Identity()
#     )
#   )
#   (up_blocks): ModuleList(
#     (0-1): 2 x TimestepEmbedSequential(
#       (0): ResidualBlock(
#         (conv1): Sequential(
#           (0): GroupNorm(32, 384, eps=1e-05, affine=True)
#           (1): SiLU()
#           (2): Conv2d(384, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#         (time_emb): Sequential(
#           (0): SiLU()
#           (1): Linear(in_features=384, out_features=192, bias=True)
#         )
#         (cond_conv): Sequential(
#           (0): Conv2d(1, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): SiLU()
#         )
#         (conv2): Sequential(
#           (0): GroupNorm(32, 192, eps=1e-05, affine=True)
#           (1): SiLU()
#           (2): Dropout(p=0, inplace=False)
#           (3): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#         (shortcut): Conv2d(384, 192, kernel_size=(1, 1), stride=(1, 1))
#       )
#     )
#     (2): TimestepEmbedSequential(
#       (0): ResidualBlock(
#         (conv1): Sequential(
#           (0): GroupNorm(32, 384, eps=1e-05, affine=True)
#           (1): SiLU()
#           (2): Conv2d(384, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#         (time_emb): Sequential(
#           (0): SiLU()
#           (1): Linear(in_features=384, out_features=192, bias=True)
#         )
#         (cond_conv): Sequential(
#           (0): Conv2d(1, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): SiLU()
#         )
#         (conv2): Sequential(
#           (0): GroupNorm(32, 192, eps=1e-05, affine=True)
#           (1): SiLU()
#           (2): Dropout(p=0, inplace=False)
#           (3): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#         (shortcut): Conv2d(384, 192, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (1): UpSample(
#         (conv): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#     )
#     (3-4): 2 x TimestepEmbedSequential(
#       (0): ResidualBlock(
#         (conv1): Sequential(
#           (0): GroupNorm(32, 384, eps=1e-05, affine=True)
#           (1): SiLU()
#           (2): Conv2d(384, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#         (time_emb): Sequential(
#           (0): SiLU()
#           (1): Linear(in_features=384, out_features=192, bias=True)
#         )
#         (cond_conv): Sequential(
#           (0): Conv2d(1, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): SiLU()
#         )
#         (conv2): Sequential(
#           (0): GroupNorm(32, 192, eps=1e-05, affine=True)
#           (1): SiLU()
#           (2): Dropout(p=0, inplace=False)
#           (3): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#         (shortcut): Conv2d(384, 192, kernel_size=(1, 1), stride=(1, 1))
#       )
#     )
#     (5): TimestepEmbedSequential(
#       (0): ResidualBlock(
#         (conv1): Sequential(
#           (0): GroupNorm(32, 288, eps=1e-05, affine=True)
#           (1): SiLU()
#           (2): Conv2d(288, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#         (time_emb): Sequential(
#           (0): SiLU()
#           (1): Linear(in_features=384, out_features=192, bias=True)
#         )
#         (cond_conv): Sequential(
#           (0): Conv2d(1, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): SiLU()
#         )
#         (conv2): Sequential(
#           (0): GroupNorm(32, 192, eps=1e-05, affine=True)
#           (1): SiLU()
#           (2): Dropout(p=0, inplace=False)
#           (3): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#         (shortcut): Conv2d(288, 192, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (1): UpSample(
#         (conv): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#     )
#     (6): TimestepEmbedSequential(
#       (0): ResidualBlock(
#         (conv1): Sequential(
#           (0): GroupNorm(32, 288, eps=1e-05, affine=True)
#           (1): SiLU()
#           (2): Conv2d(288, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#         (time_emb): Sequential(
#           (0): SiLU()
#           (1): Linear(in_features=384, out_features=96, bias=True)
#         )
#         (cond_conv): Sequential(
#           (0): Conv2d(1, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): SiLU()
#         )
#         (conv2): Sequential(
#           (0): GroupNorm(32, 96, eps=1e-05, affine=True)
#           (1): SiLU()
#           (2): Dropout(p=0, inplace=False)
#           (3): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#         (shortcut): Conv2d(288, 96, kernel_size=(1, 1), stride=(1, 1))
#       )
#     )
#     (7-8): 2 x TimestepEmbedSequential(
#       (0): ResidualBlock(
#         (conv1): Sequential(
#           (0): GroupNorm(32, 192, eps=1e-05, affine=True)
#           (1): SiLU()
#           (2): Conv2d(192, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#         (time_emb): Sequential(
#           (0): SiLU()
#           (1): Linear(in_features=384, out_features=96, bias=True)
#         )
#         (cond_conv): Sequential(
#           (0): Conv2d(1, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): SiLU()
#         )
#         (conv2): Sequential(
#           (0): GroupNorm(32, 96, eps=1e-05, affine=True)
#           (1): SiLU()
#           (2): Dropout(p=0, inplace=False)
#           (3): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#         (shortcut): Conv2d(192, 96, kernel_size=(1, 1), stride=(1, 1))
#       )
#     )
#   )
#   (out): Sequential(
#     (0): GroupNorm(32, 96, eps=1e-05, affine=True)
#     (1): SiLU()
#     (2): Conv2d(96, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   )
# )

# %%
image = next(iter(train_loader))[0][0].squeeze()
conditional = next(iter(train_loader))[1][0].squeeze()

x_start = image.float()

gaussian_diffusion = GaussianDiffusion(timesteps=500, beta_schedule='linear')

plt.figure(figsize=(16, 5))
for idx, t in enumerate([0, 100, 300, 400, 499]):
    x_noisy = gaussian_diffusion.q_sample(x_start.to(device), t=torch.tensor([t]).to(device))
    noisy_image = (x_noisy.squeeze() + 1) * 127.5
    if idx==0:
        noisy_image = (x_start.squeeze() + 1) * 127.5
    noisy_image = noisy_image.cpu().numpy().astype(np.uint8)
    plt.subplot(1, 5, 1 + idx)
    plt.imshow(noisy_image, cmap='gray')
    plt.axis("off")
    plt.title(f"t={t}")

# %%
epochs = 20
p_uncound = 0.2
len_data = len(train_loader)
time_end = time.time()
timesteps=500

diff_optimizer = torch.optim.Adam(diff_model.parameters(), lr=1e-4)
gaussian_diffusion = GaussianDiffusion(timesteps=500, beta_schedule='linear')

total_losses = []
diff_losses = []
for epoch in range(epochs):
    epoch_diff_losses = []
    epoch_total_losses = []
    for step, (images, cond_images, reg_params) in enumerate(train_loader):  
        images = images.float().to(device)
        cond_images = cond_images.float().to(device)
        reg_params = reg_params.float().to(device)
        
        time_start = time_end
        
        diff_optimizer.zero_grad()
        
        batch_size = images.shape[0]
        images = images.to(device).float()
        cond_images = cond_images.to(device).float()
        
        # random generate mask
        z_uncound = torch.rand(batch_size)
        batch_mask = (z_uncound>p_uncound).int().to(device)
        
        # sample t uniformally for every example in the batch
        t = torch.randint(0, timesteps, (batch_size,), device=device).long()
        loss, outputs, mid_block_features = gaussian_diffusion.train_losses(diff_model, images, t, cond_images, batch_mask)

        mid_block_features = mid_block_features.to(device)

        # train regression
        reg_input = (mid_block_features, reg_params)
        reg_loss = train_regressor(reg_model, reg_input, reg_optimizer, reg_criterion, epochs=1)

        total_loss = loss + reg_loss

        epoch_total_losses.append(total_loss.item())
        epoch_diff_losses.append(loss.item())

        if step % 100 == 0:
            time_end = time.time()
            print("Epoch{}/{}\t  Step{}/{}\t Loss {:.4f}\t Time {:.2f}".format(epoch+1, epochs, step+1, len_data, loss.item(), time_end-time_start))
            
        total_loss.backward()
        diff_optimizer.step()
        reg_optimizer.step()

    total_losses.append(np.array(epoch_total_losses).mean())
    diff_losses.append(np.array(epoch_diff_losses).mean())
# Out:
# Regression Training - Epoch 1/1, Loss: 1500.530029296875
# Epoch1/20	  Step1/22	 Loss 1.2732	 Time 0.50
# Regression Training - Epoch 1/1, Loss: 1404.252197265625
# Regression Training - Epoch 1/1, Loss: 507.402099609375
# Regression Training - Epoch 1/1, Loss: 585.59521484375
# Regression Training - Epoch 1/1, Loss: 409.065673828125
# Regression Training - Epoch 1/1, Loss: 606.8983764648438
# Regression Training - Epoch 1/1, Loss: 312.72161865234375
# Regression Training - Epoch 1/1, Loss: 461.0743103027344
# Regression Training - Epoch 1/1, Loss: 578.2476806640625
# Regression Training - Epoch 1/1, Loss: 297.5102233886719
# Regression Training - Epoch 1/1, Loss: 575.3272705078125
# Regression Training - Epoch 1/1, Loss: 334.7909240722656
# Regression Training - Epoch 1/1, Loss: 334.4781494140625
# Regression Training - Epoch 1/1, Loss: 303.94329833984375
# Regression Training - Epoch 1/1, Loss: 274.1864318847656
# Regression Training - Epoch 1/1, Loss: 348.20867919921875
# Regression Training - Epoch 1/1, Loss: 265.8060302734375
# Regression Training - Epoch 1/1, Loss: 253.767333984375
# Regression Training - Epoch 1/1, Loss: 214.35250854492188
# Regression Training - Epoch 1/1, Loss: 216.7577362060547
# Regression Training - Epoch 1/1, Loss: 263.84014892578125
# Regression Training - Epoch 1/1, Loss: 180.4477081298828
# Regression Training - Epoch 1/1, Loss: 204.77957153320312
# Epoch2/20	  Step1/22	 Loss 0.0489	 Time 5.64
# Regression Training - Epoch 1/1, Loss: 282.5469970703125
# Regression Training - Epoch 1/1, Loss: 224.04510498046875
# Regression Training - Epoch 1/1, Loss: 253.47308349609375
# Regression Training - Epoch 1/1, Loss: 318.2404479980469
# Regression Training - Epoch 1/1, Loss: 351.5413513183594
# Regression Training - Epoch 1/1, Loss: 261.99713134765625
# Regression Training - Epoch 1/1, Loss: 227.16424560546875
# Regression Training - Epoch 1/1, Loss: 261.283203125
# Regression Training - Epoch 1/1, Loss: 233.6904296875
# Regression Training - Epoch 1/1, Loss: 276.3548583984375
# Regression Training - Epoch 1/1, Loss: 297.2959899902344
# Regression Training - Epoch 1/1, Loss: 225.14944458007812
# Regression Training - Epoch 1/1, Loss: 283.2076110839844
# Regression Training - Epoch 1/1, Loss: 233.04489135742188
# Regression Training - Epoch 1/1, Loss: 290.8226013183594
# Regression Training - Epoch 1/1, Loss: 266.53912353515625
# Regression Training - Epoch 1/1, Loss: 249.6888427734375
# Regression Training - Epoch 1/1, Loss: 206.58103942871094
# Regression Training - Epoch 1/1, Loss: 197.3226318359375
# Regression Training - Epoch 1/1, Loss: 213.25588989257812
# Regression Training - Epoch 1/1, Loss: 209.7606658935547
# Regression Training - Epoch 1/1, Loss: 203.71783447265625
# Epoch3/20	  Step1/22	 Loss 0.0223	 Time 5.30
# Regression Training - Epoch 1/1, Loss: 190.67770385742188
# Regression Training - Epoch 1/1, Loss: 208.91964721679688
# Regression Training - Epoch 1/1, Loss: 203.4153289794922
# Regression Training - Epoch 1/1, Loss: 194.7678680419922
# Regression Training - Epoch 1/1, Loss: 191.7152099609375
# Regression Training - Epoch 1/1, Loss: 269.0843811035156
# Regression Training - Epoch 1/1, Loss: 323.6847839355469
# Regression Training - Epoch 1/1, Loss: 309.8625183105469
# Regression Training - Epoch 1/1, Loss: 261.4048156738281
# Regression Training - Epoch 1/1, Loss: 197.9693603515625
# Regression Training - Epoch 1/1, Loss: 261.08154296875
# Regression Training - Epoch 1/1, Loss: 179.90737915039062
# Regression Training - Epoch 1/1, Loss: 283.4700927734375
# Regression Training - Epoch 1/1, Loss: 233.59967041015625
# Regression Training - Epoch 1/1, Loss: 246.57888793945312
# Regression Training - Epoch 1/1, Loss: 240.8251953125
# Regression Training - Epoch 1/1, Loss: 256.6006774902344
# Regression Training - Epoch 1/1, Loss: 253.86184692382812
# Regression Training - Epoch 1/1, Loss: 186.4355926513672
# Regression Training - Epoch 1/1, Loss: 217.10806274414062
# Regression Training - Epoch 1/1, Loss: 205.9320831298828
# Regression Training - Epoch 1/1, Loss: 222.9348602294922
# Epoch4/20	  Step1/22	 Loss 0.0204	 Time 5.30
# Regression Training - Epoch 1/1, Loss: 255.6553192138672
# Regression Training - Epoch 1/1, Loss: 245.83294677734375
# Regression Training - Epoch 1/1, Loss: 354.74200439453125
# Regression Training - Epoch 1/1, Loss: 153.87405395507812
# Regression Training - Epoch 1/1, Loss: 218.1781463623047
# Regression Training - Epoch 1/1, Loss: 216.3986053466797
# Regression Training - Epoch 1/1, Loss: 260.1194763183594
# Regression Training - Epoch 1/1, Loss: 219.3169403076172
# Regression Training - Epoch 1/1, Loss: 405.47650146484375
# Regression Training - Epoch 1/1, Loss: 189.75192260742188
# Regression Training - Epoch 1/1, Loss: 262.8970947265625
# Regression Training - Epoch 1/1, Loss: 281.0779724121094
# Regression Training - Epoch 1/1, Loss: 207.46444702148438
# Regression Training - Epoch 1/1, Loss: 231.9576873779297
# Regression Training - Epoch 1/1, Loss: 267.7619323730469
# Regression Training - Epoch 1/1, Loss: 249.8285369873047
# Regression Training - Epoch 1/1, Loss: 199.03955078125
# Regression Training - Epoch 1/1, Loss: 242.2686004638672
# Regression Training - Epoch 1/1, Loss: 263.15875244140625
# Regression Training - Epoch 1/1, Loss: 228.6787567138672
# Regression Training - Epoch 1/1, Loss: 285.3365173339844
# Regression Training - Epoch 1/1, Loss: 246.65264892578125
# Epoch5/20	  Step1/22	 Loss 0.0123	 Time 5.30
# Regression Training - Epoch 1/1, Loss: 223.6815185546875
# Regression Training - Epoch 1/1, Loss: 251.1938934326172
# Regression Training - Epoch 1/1, Loss: 293.9609375
# Regression Training - Epoch 1/1, Loss: 162.79502868652344
# Regression Training - Epoch 1/1, Loss: 286.491455078125
# Regression Training - Epoch 1/1, Loss: 262.18121337890625
# Regression Training - Epoch 1/1, Loss: 242.52386474609375
# Regression Training - Epoch 1/1, Loss: 273.0963134765625
# Regression Training - Epoch 1/1, Loss: 191.27178955078125
# Regression Training - Epoch 1/1, Loss: 255.47988891601562
# Regression Training - Epoch 1/1, Loss: 248.86538696289062
# Regression Training - Epoch 1/1, Loss: 220.37033081054688
# Regression Training - Epoch 1/1, Loss: 237.14068603515625
# Regression Training - Epoch 1/1, Loss: 209.8865966796875
# Regression Training - Epoch 1/1, Loss: 212.20724487304688
# Regression Training - Epoch 1/1, Loss: 197.8270263671875
# Regression Training - Epoch 1/1, Loss: 229.40414428710938
# Regression Training - Epoch 1/1, Loss: 273.6385192871094
# Regression Training - Epoch 1/1, Loss: 224.60073852539062
# Regression Training - Epoch 1/1, Loss: 221.7623291015625
# Regression Training - Epoch 1/1, Loss: 185.47572326660156
# Regression Training - Epoch 1/1, Loss: 264.68072509765625
# Epoch6/20	  Step1/22	 Loss 0.0163	 Time 5.30
# Regression Training - Epoch 1/1, Loss: 213.8878173828125
# Regression Training - Epoch 1/1, Loss: 283.2328796386719
# Regression Training - Epoch 1/1, Loss: 201.3854217529297
# Regression Training - Epoch 1/1, Loss: 244.3130340576172
# Regression Training - Epoch 1/1, Loss: 222.8697509765625
# Regression Training - Epoch 1/1, Loss: 295.3016662597656
# Regression Training - Epoch 1/1, Loss: 190.5417938232422
# Regression Training - Epoch 1/1, Loss: 146.5662841796875
# Regression Training - Epoch 1/1, Loss: 255.2727508544922
# Regression Training - Epoch 1/1, Loss: 221.77218627929688
# Regression Training - Epoch 1/1, Loss: 207.09835815429688
# Regression Training - Epoch 1/1, Loss: 205.71612548828125
# Regression Training - Epoch 1/1, Loss: 241.8123016357422
# Regression Training - Epoch 1/1, Loss: 263.4278259277344
# Regression Training - Epoch 1/1, Loss: 259.62451171875
# Regression Training - Epoch 1/1, Loss: 224.6788787841797
# Regression Training - Epoch 1/1, Loss: 154.69430541992188
# Regression Training - Epoch 1/1, Loss: 221.1472625732422
# Regression Training - Epoch 1/1, Loss: 223.959716796875
# Regression Training - Epoch 1/1, Loss: 239.1478271484375
# Regression Training - Epoch 1/1, Loss: 176.31613159179688
# Regression Training - Epoch 1/1, Loss: 409.3035888671875
# Epoch7/20	  Step1/22	 Loss 0.0102	 Time 5.30
# Regression Training - Epoch 1/1, Loss: 324.3447570800781
# Regression Training - Epoch 1/1, Loss: 230.94461059570312
# Regression Training - Epoch 1/1, Loss: 286.2237243652344
# Regression Training - Epoch 1/1, Loss: 265.7022705078125
# Regression Training - Epoch 1/1, Loss: 214.78050231933594
# Regression Training - Epoch 1/1, Loss: 285.482177734375
# Regression Training - Epoch 1/1, Loss: 392.87255859375
# Regression Training - Epoch 1/1, Loss: 262.5426025390625
# Regression Training - Epoch 1/1, Loss: 245.98361206054688
# Regression Training - Epoch 1/1, Loss: 163.78573608398438
# Regression Training - Epoch 1/1, Loss: 264.44647216796875
# Regression Training - Epoch 1/1, Loss: 233.97964477539062
# Regression Training - Epoch 1/1, Loss: 236.734619140625
# Regression Training - Epoch 1/1, Loss: 211.3802490234375
# Regression Training - Epoch 1/1, Loss: 181.76414489746094
# Regression Training - Epoch 1/1, Loss: 289.33441162109375
# Regression Training - Epoch 1/1, Loss: 202.06369018554688
# Regression Training - Epoch 1/1, Loss: 193.65594482421875
# Regression Training - Epoch 1/1, Loss: 190.14596557617188
# Regression Training - Epoch 1/1, Loss: 226.47653198242188
# Regression Training - Epoch 1/1, Loss: 231.0062713623047
# Regression Training - Epoch 1/1, Loss: 184.8690643310547
# Epoch8/20	  Step1/22	 Loss 0.0084	 Time 5.30
# Regression Training - Epoch 1/1, Loss: 243.41989135742188
# Regression Training - Epoch 1/1, Loss: 188.12997436523438
# Regression Training - Epoch 1/1, Loss: 180.63192749023438
# Regression Training - Epoch 1/1, Loss: 256.78204345703125
# Regression Training - Epoch 1/1, Loss: 206.7438201904297
# Regression Training - Epoch 1/1, Loss: 179.40618896484375
# Regression Training - Epoch 1/1, Loss: 284.4335632324219
# Regression Training - Epoch 1/1, Loss: 274.3559265136719
# Regression Training - Epoch 1/1, Loss: 183.16958618164062
# Regression Training - Epoch 1/1, Loss: 313.13671875
# Regression Training - Epoch 1/1, Loss: 174.1221160888672
# Regression Training - Epoch 1/1, Loss: 260.79730224609375
# Regression Training - Epoch 1/1, Loss: 162.70162963867188
# Regression Training - Epoch 1/1, Loss: 234.48483276367188
# Regression Training - Epoch 1/1, Loss: 194.0648651123047
# Regression Training - Epoch 1/1, Loss: 261.70697021484375
# Regression Training - Epoch 1/1, Loss: 206.49710083007812
# Regression Training - Epoch 1/1, Loss: 131.9221954345703
# Regression Training - Epoch 1/1, Loss: 229.52960205078125
# Regression Training - Epoch 1/1, Loss: 198.78575134277344
# Regression Training - Epoch 1/1, Loss: 524.0772094726562
# Regression Training - Epoch 1/1, Loss: 250.38412475585938
# Epoch9/20	  Step1/22	 Loss 0.0055	 Time 5.30
# Regression Training - Epoch 1/1, Loss: 298.4710388183594
# Regression Training - Epoch 1/1, Loss: 183.43084716796875
# Regression Training - Epoch 1/1, Loss: 190.84414672851562
# Regression Training - Epoch 1/1, Loss: 221.60336303710938
# Regression Training - Epoch 1/1, Loss: 217.4366912841797
# Regression Training - Epoch 1/1, Loss: 250.66036987304688
# Regression Training - Epoch 1/1, Loss: 203.98922729492188
# Regression Training - Epoch 1/1, Loss: 248.26693725585938
# Regression Training - Epoch 1/1, Loss: 390.5662841796875
# Regression Training - Epoch 1/1, Loss: 237.4820556640625
# Regression Training - Epoch 1/1, Loss: 317.06243896484375
# Regression Training - Epoch 1/1, Loss: 299.40826416015625
# Regression Training - Epoch 1/1, Loss: 239.10458374023438
# Regression Training - Epoch 1/1, Loss: 256.12896728515625
# Regression Training - Epoch 1/1, Loss: 467.5643005371094
# Regression Training - Epoch 1/1, Loss: 222.34823608398438
# Regression Training - Epoch 1/1, Loss: 291.48504638671875
# Regression Training - Epoch 1/1, Loss: 230.49142456054688
# Regression Training - Epoch 1/1, Loss: 372.43463134765625
# Regression Training - Epoch 1/1, Loss: 171.87655639648438
# Regression Training - Epoch 1/1, Loss: 151.73858642578125
# Regression Training - Epoch 1/1, Loss: 412.06378173828125
# Epoch10/20	  Step1/22	 Loss 0.0056	 Time 5.30
# Regression Training - Epoch 1/1, Loss: 425.61370849609375
# Regression Training - Epoch 1/1, Loss: 176.30221557617188
# Regression Training - Epoch 1/1, Loss: 326.9119873046875
# Regression Training - Epoch 1/1, Loss: 265.89093017578125
# Regression Training - Epoch 1/1, Loss: 284.72369384765625
# Regression Training - Epoch 1/1, Loss: 229.33636474609375
# Regression Training - Epoch 1/1, Loss: 357.19921875
# Regression Training - Epoch 1/1, Loss: 265.19671630859375
# Regression Training - Epoch 1/1, Loss: 272.55859375
# Regression Training - Epoch 1/1, Loss: 219.26589965820312
# Regression Training - Epoch 1/1, Loss: 293.8421630859375
# Regression Training - Epoch 1/1, Loss: 195.104248046875
# Regression Training - Epoch 1/1, Loss: 226.74789428710938
# Regression Training - Epoch 1/1, Loss: 289.19305419921875
# Regression Training - Epoch 1/1, Loss: 207.98971557617188
# Regression Training - Epoch 1/1, Loss: 276.3531799316406
# Regression Training - Epoch 1/1, Loss: 184.1797332763672
# Regression Training - Epoch 1/1, Loss: 322.3779602050781
# Regression Training - Epoch 1/1, Loss: 235.7225799560547
# Regression Training - Epoch 1/1, Loss: 199.66232299804688
# Regression Training - Epoch 1/1, Loss: 104.17803192138672
# Regression Training - Epoch 1/1, Loss: 403.1442565917969
# Epoch11/20	  Step1/22	 Loss 0.0080	 Time 5.30
# Regression Training - Epoch 1/1, Loss: 309.9527893066406
# Regression Training - Epoch 1/1, Loss: 296.1038818359375
# Regression Training - Epoch 1/1, Loss: 342.9515075683594
# Regression Training - Epoch 1/1, Loss: 331.868896484375
# Regression Training - Epoch 1/1, Loss: 358.93634033203125
# Regression Training - Epoch 1/1, Loss: 203.529541015625
# Regression Training - Epoch 1/1, Loss: 157.84483337402344
# Regression Training - Epoch 1/1, Loss: 357.697265625
# Regression Training - Epoch 1/1, Loss: 321.4336853027344
# Regression Training - Epoch 1/1, Loss: 225.276611328125
# Regression Training - Epoch 1/1, Loss: 203.44314575195312
# Regression Training - Epoch 1/1, Loss: 274.5492858886719
# Regression Training - Epoch 1/1, Loss: 337.7205505371094
# Regression Training - Epoch 1/1, Loss: 173.47515869140625
# Regression Training - Epoch 1/1, Loss: 237.5704803466797
# Regression Training - Epoch 1/1, Loss: 195.67324829101562
# Regression Training - Epoch 1/1, Loss: 393.0008544921875
# Regression Training - Epoch 1/1, Loss: 170.207275390625
# Regression Training - Epoch 1/1, Loss: 194.71469116210938
# Regression Training - Epoch 1/1, Loss: 217.5914306640625
# Regression Training - Epoch 1/1, Loss: 164.5576629638672
# Regression Training - Epoch 1/1, Loss: 263.0655212402344
# Epoch12/20	  Step1/22	 Loss 0.0074	 Time 5.30
# Regression Training - Epoch 1/1, Loss: 254.7324676513672
# Regression Training - Epoch 1/1, Loss: 167.71759033203125
# Regression Training - Epoch 1/1, Loss: 222.00030517578125
# Regression Training - Epoch 1/1, Loss: 273.16064453125
# Regression Training - Epoch 1/1, Loss: 246.11727905273438
# Regression Training - Epoch 1/1, Loss: 203.7565155029297
# Regression Training - Epoch 1/1, Loss: 236.9677734375
# Regression Training - Epoch 1/1, Loss: 284.7823486328125
# Regression Training - Epoch 1/1, Loss: 189.1129150390625
# Regression Training - Epoch 1/1, Loss: 194.38638305664062
# Regression Training - Epoch 1/1, Loss: 246.1004638671875
# Regression Training - Epoch 1/1, Loss: 272.5279541015625
# Regression Training - Epoch 1/1, Loss: 147.30776977539062
# Regression Training - Epoch 1/1, Loss: 169.51821899414062
# Regression Training - Epoch 1/1, Loss: 177.492431640625
# Regression Training - Epoch 1/1, Loss: 182.55416870117188
# Regression Training - Epoch 1/1, Loss: 188.111572265625
# Regression Training - Epoch 1/1, Loss: 186.33714294433594
# Regression Training - Epoch 1/1, Loss: 196.36105346679688
# Regression Training - Epoch 1/1, Loss: 185.15567016601562
# Regression Training - Epoch 1/1, Loss: 109.43924713134766
# Regression Training - Epoch 1/1, Loss: 140.90771484375
# Epoch13/20	  Step1/22	 Loss 0.0121	 Time 5.30
# Regression Training - Epoch 1/1, Loss: 173.96963500976562
# Regression Training - Epoch 1/1, Loss: 193.5460662841797
# Regression Training - Epoch 1/1, Loss: 191.2312469482422
# Regression Training - Epoch 1/1, Loss: 195.69798278808594
# Regression Training - Epoch 1/1, Loss: 171.5947723388672
# Regression Training - Epoch 1/1, Loss: 245.07308959960938
# Regression Training - Epoch 1/1, Loss: 179.76290893554688
# Regression Training - Epoch 1/1, Loss: 213.44967651367188
# Regression Training - Epoch 1/1, Loss: 188.14434814453125
# Regression Training - Epoch 1/1, Loss: 174.12283325195312
# Regression Training - Epoch 1/1, Loss: 208.67745971679688
# Regression Training - Epoch 1/1, Loss: 173.57943725585938
# Regression Training - Epoch 1/1, Loss: 203.72384643554688
# Regression Training - Epoch 1/1, Loss: 221.86651611328125
# Regression Training - Epoch 1/1, Loss: 185.7715301513672
# Regression Training - Epoch 1/1, Loss: 323.11273193359375
# Regression Training - Epoch 1/1, Loss: 216.55859375
# Regression Training - Epoch 1/1, Loss: 174.23240661621094
# Regression Training - Epoch 1/1, Loss: 228.5461883544922
# Regression Training - Epoch 1/1, Loss: 270.40576171875
# Regression Training - Epoch 1/1, Loss: 268.1913146972656
# Regression Training - Epoch 1/1, Loss: 126.92265319824219
# Epoch14/20	  Step1/22	 Loss 0.0069	 Time 5.30
# Regression Training - Epoch 1/1, Loss: 198.90859985351562
# Regression Training - Epoch 1/1, Loss: 177.93313598632812
# Regression Training - Epoch 1/1, Loss: 193.95065307617188
# Regression Training - Epoch 1/1, Loss: 205.0553436279297
# Regression Training - Epoch 1/1, Loss: 217.72012329101562
# Regression Training - Epoch 1/1, Loss: 218.91473388671875
# Regression Training - Epoch 1/1, Loss: 231.01980590820312
# Regression Training - Epoch 1/1, Loss: 156.80206298828125
# Regression Training - Epoch 1/1, Loss: 196.59237670898438
# Regression Training - Epoch 1/1, Loss: 163.6272735595703
# Regression Training - Epoch 1/1, Loss: 161.4047088623047
# Regression Training - Epoch 1/1, Loss: 298.246337890625
# Regression Training - Epoch 1/1, Loss: 199.042724609375
# Regression Training - Epoch 1/1, Loss: 161.0919952392578
# Regression Training - Epoch 1/1, Loss: 171.2880096435547
# Regression Training - Epoch 1/1, Loss: 258.7533264160156
# Regression Training - Epoch 1/1, Loss: 186.96783447265625
# Regression Training - Epoch 1/1, Loss: 135.806640625
# Regression Training - Epoch 1/1, Loss: 198.3114471435547
# Regression Training - Epoch 1/1, Loss: 191.8272705078125
# Regression Training - Epoch 1/1, Loss: 147.35507202148438
# Regression Training - Epoch 1/1, Loss: 192.3272705078125
# Epoch15/20	  Step1/22	 Loss 0.0107	 Time 5.31
# Regression Training - Epoch 1/1, Loss: 203.05758666992188
# Regression Training - Epoch 1/1, Loss: 172.04440307617188
# Regression Training - Epoch 1/1, Loss: 168.5797882080078
# Regression Training - Epoch 1/1, Loss: 141.7476806640625
# Regression Training - Epoch 1/1, Loss: 146.04669189453125
# Regression Training - Epoch 1/1, Loss: 214.02593994140625
# Regression Training - Epoch 1/1, Loss: 190.8143310546875
# Regression Training - Epoch 1/1, Loss: 137.6493377685547
# Regression Training - Epoch 1/1, Loss: 219.32382202148438
# Regression Training - Epoch 1/1, Loss: 353.458251953125
# Regression Training - Epoch 1/1, Loss: 183.69163513183594
# Regression Training - Epoch 1/1, Loss: 253.53353881835938
# Regression Training - Epoch 1/1, Loss: 192.7684783935547
# Regression Training - Epoch 1/1, Loss: 212.1396484375
# Regression Training - Epoch 1/1, Loss: 281.33099365234375
# Regression Training - Epoch 1/1, Loss: 167.46669006347656
# Regression Training - Epoch 1/1, Loss: 360.26776123046875
# Regression Training - Epoch 1/1, Loss: 201.84654235839844
# Regression Training - Epoch 1/1, Loss: 229.91317749023438
# Regression Training - Epoch 1/1, Loss: 136.35325622558594
# Regression Training - Epoch 1/1, Loss: 160.701904296875
# Regression Training - Epoch 1/1, Loss: 169.80947875976562
# Epoch16/20	  Step1/22	 Loss 0.0049	 Time 5.30
# Regression Training - Epoch 1/1, Loss: 165.72494506835938
# Regression Training - Epoch 1/1, Loss: 155.9564666748047
# Regression Training - Epoch 1/1, Loss: 165.33175659179688
# Regression Training - Epoch 1/1, Loss: 190.780517578125
# Regression Training - Epoch 1/1, Loss: 154.30255126953125
# Regression Training - Epoch 1/1, Loss: 176.5413818359375
# Regression Training - Epoch 1/1, Loss: 256.7122802734375
# Regression Training - Epoch 1/1, Loss: 141.4744110107422
# Regression Training - Epoch 1/1, Loss: 179.38861083984375
# Regression Training - Epoch 1/1, Loss: 219.83270263671875
# Regression Training - Epoch 1/1, Loss: 136.92701721191406
# Regression Training - Epoch 1/1, Loss: 193.37350463867188
# Regression Training - Epoch 1/1, Loss: 179.63739013671875
# Regression Training - Epoch 1/1, Loss: 151.47637939453125
# Regression Training - Epoch 1/1, Loss: 204.62994384765625
# Regression Training - Epoch 1/1, Loss: 222.25765991210938
# Regression Training - Epoch 1/1, Loss: 157.21646118164062
# Regression Training - Epoch 1/1, Loss: 232.47726440429688
# Regression Training - Epoch 1/1, Loss: 133.11105346679688
# Regression Training - Epoch 1/1, Loss: 163.61737060546875
# Regression Training - Epoch 1/1, Loss: 200.49241638183594
# Regression Training - Epoch 1/1, Loss: 189.4349822998047
# Epoch17/20	  Step1/22	 Loss 0.0159	 Time 5.30
# Regression Training - Epoch 1/1, Loss: 140.54046630859375
# Regression Training - Epoch 1/1, Loss: 152.55825805664062
# Regression Training - Epoch 1/1, Loss: 229.3210906982422
# Regression Training - Epoch 1/1, Loss: 173.0433349609375
# Regression Training - Epoch 1/1, Loss: 225.316650390625
# Regression Training - Epoch 1/1, Loss: 155.06622314453125
# Regression Training - Epoch 1/1, Loss: 177.475830078125
# Regression Training - Epoch 1/1, Loss: 188.6405029296875
# Regression Training - Epoch 1/1, Loss: 192.64401245117188
# Regression Training - Epoch 1/1, Loss: 229.00845336914062
# Regression Training - Epoch 1/1, Loss: 129.6914520263672
# Regression Training - Epoch 1/1, Loss: 190.30564880371094
# Regression Training - Epoch 1/1, Loss: 174.43966674804688
# Regression Training - Epoch 1/1, Loss: 147.2137451171875
# Regression Training - Epoch 1/1, Loss: 179.47482299804688
# Regression Training - Epoch 1/1, Loss: 234.21881103515625
# Regression Training - Epoch 1/1, Loss: 153.07102966308594
# Regression Training - Epoch 1/1, Loss: 156.93649291992188
# Regression Training - Epoch 1/1, Loss: 253.58822631835938
# Regression Training - Epoch 1/1, Loss: 229.26437377929688
# Regression Training - Epoch 1/1, Loss: 144.77964782714844
# Regression Training - Epoch 1/1, Loss: 149.31585693359375
# Epoch18/20	  Step1/22	 Loss 0.0076	 Time 5.30
# Regression Training - Epoch 1/1, Loss: 172.06768798828125
# Regression Training - Epoch 1/1, Loss: 309.99774169921875
# Regression Training - Epoch 1/1, Loss: 267.80047607421875
# Regression Training - Epoch 1/1, Loss: 229.45733642578125
# Regression Training - Epoch 1/1, Loss: 244.2686767578125
# Regression Training - Epoch 1/1, Loss: 235.37255859375
# Regression Training - Epoch 1/1, Loss: 119.66961669921875
# Regression Training - Epoch 1/1, Loss: 173.92245483398438
# Regression Training - Epoch 1/1, Loss: 226.89218139648438
# Regression Training - Epoch 1/1, Loss: 231.180908203125
# Regression Training - Epoch 1/1, Loss: 131.2750244140625
# Regression Training - Epoch 1/1, Loss: 179.40402221679688
# Regression Training - Epoch 1/1, Loss: 176.39794921875
# Regression Training - Epoch 1/1, Loss: 190.7866668701172
# Regression Training - Epoch 1/1, Loss: 170.49778747558594
# Regression Training - Epoch 1/1, Loss: 156.37367248535156
# Regression Training - Epoch 1/1, Loss: 184.7686767578125
# Regression Training - Epoch 1/1, Loss: 143.7447967529297
# Regression Training - Epoch 1/1, Loss: 157.06436157226562
# Regression Training - Epoch 1/1, Loss: 154.65452575683594
# Regression Training - Epoch 1/1, Loss: 154.05796813964844
# Regression Training - Epoch 1/1, Loss: 192.032958984375
# Epoch19/20	  Step1/22	 Loss 0.0053	 Time 5.30
# Regression Training - Epoch 1/1, Loss: 195.3976287841797
# Regression Training - Epoch 1/1, Loss: 151.8787078857422
# Regression Training - Epoch 1/1, Loss: 129.06906127929688
# Regression Training - Epoch 1/1, Loss: 279.4803466796875
# Regression Training - Epoch 1/1, Loss: 103.91912841796875
# Regression Training - Epoch 1/1, Loss: 187.29833984375
# Regression Training - Epoch 1/1, Loss: 178.55908203125
# Regression Training - Epoch 1/1, Loss: 190.6052703857422
# Regression Training - Epoch 1/1, Loss: 208.45346069335938
# Regression Training - Epoch 1/1, Loss: 185.3724365234375
# Regression Training - Epoch 1/1, Loss: 199.8718719482422
# Regression Training - Epoch 1/1, Loss: 135.34664916992188
# Regression Training - Epoch 1/1, Loss: 128.52586364746094
# Regression Training - Epoch 1/1, Loss: 155.57498168945312
# Regression Training - Epoch 1/1, Loss: 180.58116149902344
# Regression Training - Epoch 1/1, Loss: 167.1650390625
# Regression Training - Epoch 1/1, Loss: 195.7289276123047
# Regression Training - Epoch 1/1, Loss: 158.90252685546875
# Regression Training - Epoch 1/1, Loss: 230.15988159179688
# Regression Training - Epoch 1/1, Loss: 161.07415771484375
# Regression Training - Epoch 1/1, Loss: 17.267189025878906
# Regression Training - Epoch 1/1, Loss: 194.25204467773438
# Epoch20/20	  Step1/22	 Loss 0.0082	 Time 5.30
# Regression Training - Epoch 1/1, Loss: 195.84686279296875
# Regression Training - Epoch 1/1, Loss: 157.23049926757812
# Regression Training - Epoch 1/1, Loss: 160.82424926757812
# Regression Training - Epoch 1/1, Loss: 167.29254150390625
# Regression Training - Epoch 1/1, Loss: 319.6645202636719
# Regression Training - Epoch 1/1, Loss: 187.55906677246094
# Regression Training - Epoch 1/1, Loss: 172.95445251464844
# Regression Training - Epoch 1/1, Loss: 271.1797790527344
# Regression Training - Epoch 1/1, Loss: 152.0528564453125
# Regression Training - Epoch 1/1, Loss: 189.68560791015625
# Regression Training - Epoch 1/1, Loss: 164.96807861328125
# Regression Training - Epoch 1/1, Loss: 197.7364959716797
# Regression Training - Epoch 1/1, Loss: 183.99185180664062
# Regression Training - Epoch 1/1, Loss: 202.79063415527344
# Regression Training - Epoch 1/1, Loss: 147.5102081298828
# Regression Training - Epoch 1/1, Loss: 127.47894287109375
# Regression Training - Epoch 1/1, Loss: 184.25421142578125
# Regression Training - Epoch 1/1, Loss: 151.10147094726562
# Regression Training - Epoch 1/1, Loss: 96.22572326660156
# Regression Training - Epoch 1/1, Loss: 156.78396606445312
# Regression Training - Epoch 1/1, Loss: 109.24659729003906

# %%
def plot_loss_curve(losses, title, epochs=20):
    xticks = list(range(epochs))
    plt.figure(figsize=(10, 5))
    plt.plot(losses, label='Diffusion Loss')
    # plt.plot(total_loss, label='Total Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.title(title)
    plt.legend()
    plt.xticks(xticks)
    plt.show()

# Example usage

plot_loss_curve(diff_losses, 'Regression Guided Diffusion - Diffusion Loss')
plot_loss_curve(total_losses, 'Regression Guided Diffusion - Total Loss')

# %%
data_iter = iter(test_loader)
input_img, cond_img, _ = next(data_iter)

# Ensure images are on the correct device and of type float32
input_img = input_img.to(device).float()
cond_img = cond_img.to(device).float()

# Define the image size and channels (modify as per your requirements)
image_size = input_img.shape[-1]
channels = input_img.shape[1]

# Call the sample method
generated_images = gaussian_diffusion.sample(
    model=diff_model,
    image_size=image_size,
    cond_img=cond_img,
    batch_size=32,  # Set the desired batch size
    channels=channels,
    w=2,
    clip_denoised=True
)

grid_size = int(np.ceil(np.sqrt(generated_images[-1].shape[0])))

# Plot the images
fig, axes = plt.subplots(grid_size, grid_size, figsize=(10, 10))

# Remove axis for each subplot
for ax in axes.flatten():
    ax.axis('off')

# Plot each image
for i, ax in enumerate(axes.flatten()):
    if i < generated_images[-1].shape[0]:
        ax.imshow(generated_images[-1][i].transpose(1, 2, 0), cmap='gray')

plt.tight_layout()
plt.show()
# Out:
# sampling loop time step: 100%|████████████████████████████████████████████████████████| 500/500 [01:21<00:00,  6.13it/s]

# %%
def mean_prediction(pred_arr):
    imgs = np.array(pred_arr)
    avg = np.mean(imgs, axis=0)
    
    return avg

data_iter = iter(test_loader)
input_img, cond_img, reg_params = next(data_iter)

# Ensure images are on the correct device and of type float32
input_img = input_img.to(device).float()
cond_img = cond_img.to(device).float()

# Define the image size and channels (modify as per your requirements)
image_size = input_img.shape[-1]
channels = input_img.shape[1]

# Call the sample method
generated_image_arr = []
for idx in range(10):
    generated_images = gaussian_diffusion.sample(
        model=diff_model,
        image_size=image_size,
        cond_img=cond_img,
        batch_size=32,  # Set the desired batch size
        channels=channels,
        w=2,
        clip_denoised=True
    )
    generated_image_arr.append(generated_images[-1].squeeze())

mean_preds = mean_prediction(generated_image_arr)

grid_size = int(np.ceil(np.sqrt(mean_preds.shape[0])))

# Plot the images
fig, axes = plt.subplots(grid_size, grid_size, figsize=(10, 10))

# Remove axis for each subplot
for ax in axes.flatten():
    ax.axis('off')

# Plot each image
for i, ax in enumerate(axes.flatten()):
    if i < mean_preds.shape[0]:
        ax.imshow(mean_preds[i], cmap='gray')

plt.tight_layout()
plt.show()
# Out:
# sampling loop time step: 100%|████████████████████████████████████████████████████████| 500/500 [01:21<00:00,  6.14it/s]
# sampling loop time step: 100%|████████████████████████████████████████████████████████| 500/500 [01:21<00:00,  6.15it/s]
# sampling loop time step: 100%|████████████████████████████████████████████████████████| 500/500 [01:21<00:00,  6.14it/s]
# sampling loop time step: 100%|████████████████████████████████████████████████████████| 500/500 [01:21<00:00,  6.15it/s]
# sampling loop time step: 100%|████████████████████████████████████████████████████████| 500/500 [01:21<00:00,  6.15it/s]
# sampling loop time step: 100%|████████████████████████████████████████████████████████| 500/500 [01:21<00:00,  6.15it/s]
# sampling loop time step: 100%|████████████████████████████████████████████████████████| 500/500 [01:21<00:00,  6.15it/s]
# sampling loop time step: 100%|████████████████████████████████████████████████████████| 500/500 [01:21<00:00,  6.15it/s]
# sampling loop time step: 100%|████████████████████████████████████████████████████████| 500/500 [01:21<00:00,  6.15it/s]
# sampling loop time step: 100%|████████████████████████████████████████████████████████| 500/500 [01:21<00:00,  6.15it/s]

# %%
input_img = input_img.cpu().squeeze()
grid_size = int(np.ceil(np.sqrt(input_img.shape[0])))

# Plot the images
fig, axes = plt.subplots(grid_size, grid_size, figsize=(10, 10))

# Remove axis for each subplot
for ax in axes.flatten():
    ax.axis('off')

# Plot each image
for i, ax in enumerate(axes.flatten()):
    if i < mean_preds.shape[0]:
        ax.imshow(input_img[i], cmap='gray')

plt.tight_layout()
plt.show()

# %%
MODEL_SAVE_PATH = os.path.join(VOL_DIR, 'results/ckpts/gde_ensemble_model_4_64x64_simData_regGuided_noDataAug.h5')
torch.save(diff_model, MODEL_SAVE_PATH)

# %% [markdown]
# ## Post Processing - Thresholding

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from scipy.ndimage import gaussian_filter, binary_opening, binary_closing

def adaptive_threshold(image, sigma=1.0, morph_size=3):
    # Normalize image to range [0, 1] from [-1, 1]
    normalized_image = (image + 1) / 2.0
    
    # Apply Gaussian filter to smooth the image (optional, helps with noise)
    smoothed_image = gaussian_filter(normalized_image, sigma=sigma)
    
    # Flatten the smoothed image
    pixel_values = smoothed_image.flatten().reshape(-1, 1)
    
    # Perform K-means clustering with 2 clusters
    kmeans = KMeans(n_clusters=2, random_state=0)
    kmeans.fit(pixel_values)
    labels = kmeans.labels_
    
    # Determine which cluster is the light region
    cluster_means = kmeans.cluster_centers_.flatten()
    light_cluster = np.argmax(cluster_means)
    
    # Create a binary image based on the cluster labels
    binary_image = np.where(labels == light_cluster, 1, 0)
    binary_image = binary_image.reshape(normalized_image.shape)
    
    # Perform morphological operations to refine the regions
    binary_image = binary_opening(binary_image, structure=np.ones((morph_size, morph_size)))
    binary_image = binary_closing(binary_image, structure=np.ones((morph_size, morph_size)))
    
    return binary_image

# %%
grid_size = int(np.ceil(np.sqrt(generated_images[-1].shape[0])))

# Plot the images
fig, axes = plt.subplots(grid_size, grid_size, figsize=(10, 10))

# Remove axis for each subplot
for ax in axes.flatten():
    ax.axis('off')

# Plot each image
for i, ax in enumerate(axes.flatten()):
    if i < mean_preds.shape[0]:
        img = mean_preds[i].squeeze()
        ax.imshow(adaptive_threshold(img, sigma=1, morph_size=3), cmap='binary_r')

plt.tight_layout()
plt.show()
