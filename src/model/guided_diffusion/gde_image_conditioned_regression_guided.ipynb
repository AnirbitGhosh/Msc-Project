# %%
import os
import math
from abc import abstractmethod

from PIL import Image
import requests
import numpy as np
import time
import torch
import torch.nn as nn
import torch.nn.functional as F
from torchvision import datasets, transforms
from tqdm import tqdm
import matplotlib.pyplot as plt
from torchvision import transforms, datasets
from torch.utils.data import Dataset, DataLoader
import pickle
import pandas as pd
from PIL import Image
import cv2

# %matplotlib inline
# Out:
# /tmp/ipykernel_904259/3285331951.py:18: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
VOL_DIR = "/vol/bitbucket/ag323/diss_ag"
device = "cuda" if torch.cuda.is_available() else "cpu"

# %% [markdown]
# ## Unet and Gaussian Diffusion

# %%
def timestep_embedding(timesteps, dim, max_period=1000):
    half = dim // 2
    freqs = torch.exp(
        -math.log(max_period) * torch.arange(start=0, end=half, dtype=torch.float32) / half
    ).to(device=timesteps.device)
    args = timesteps[:, None].float() * freqs[None]
    embedding = torch.cat([torch.cos(args), torch.sin(args)], dim=-1)
    if dim % 2:
        embedding = torch.cat([embedding, torch.zeros_like(embedding[:, :1])], dim=-1)
    return embedding

class TimestepBlock(nn.Module):
    @abstractmethod
    def forward(self, x, emb):
        """
        Apply the module to `x` given `emb` timestep embeddings.
        """

class TimestepEmbedSequential(nn.Sequential, TimestepBlock):
    """
    A sequential module that passes timestep embeddings to the children that
    support it as an extra input.
    """
    def forward(self, x, t_emb, c_emb, mask):
        for layer in self:
            if(isinstance(layer, TimestepBlock)):
                x = layer(x, t_emb, c_emb, mask)
            else:
                x = layer(x)
            return x

def norm_layer(channels):
    return nn.GroupNorm(32, channels)

class ResidualBlock(TimestepBlock):
    def __init__(self, in_channels, out_channels, time_channels, cond_channels, dropout):
        super().__init__()
        self.conv1 = nn.Sequential(
            norm_layer(in_channels),
            nn.SiLU(),
            nn.Conv2d(in_channels, out_channels, kernel_size=3, padding=1)
        )
        
        self.time_emb = nn.Sequential(
            nn.SiLU(),
            nn.Linear(time_channels, out_channels)
        )
        
        self.cond_conv = nn.Sequential(
            nn.Conv2d(cond_channels, out_channels, kernel_size=3, padding=1),
            nn.SiLU()
        )
        
        self.conv2 = nn.Sequential(
            norm_layer(out_channels),
            nn.SiLU(),
            nn.Dropout(p=dropout),
            nn.Conv2d(out_channels, out_channels, kernel_size=3, padding=1)
        )
        
        if in_channels != out_channels:
            self.shortcut = nn.Conv2d(in_channels, out_channels, kernel_size=1)
        else:
            self.shortcut = nn.Identity()
    
    def forward(self, x, t, cond_img, mask):
        h = self.conv1(x)
        emb_t = self.time_emb(t)
        emb_cond = self.cond_conv(cond_img) * mask[:, None, None, None]
        h += (emb_t[:, :, None, None] + emb_cond)
        h = self.conv2(h)
        
        return h + self.shortcut(x)
    
class AttentionBlock(nn.Module):
    def __init__(self, channels, num_heads=1):
        super().__init__()
        self.num_heads = num_heads
        assert channels % num_heads == 0
        
        self.norm = norm_layer(channels)
        self.qkv = nn.Conv2d(channels, channels * 3, kernel_size=1, bias=False)
        self.proj = nn.Conv2d(channels, channels, kernel_size=1)
        
    def forward(self, x):
        B, C, H, W = x.shape
        qkv = self.qkv(self.norm(x))
        q, k, v = qkv.reshape(B *  self.num_heads, -1, H * W).chunk(3, dim=1)
        scale = 1. / math.sqrt(math.sqrt(C // self.num_heads))
        attn = torch.einsum("bct,bcs->bts", q * scale, k * scale)
        attn = attn.softmax(dim=-1)
        h = torch.einsum("bts,bcs->bct", attn, v)
        h = h.reshape(B, -1, H, W)
        h = self.proj(h)
        return h + x
    
class UpSample(nn.Module):
    def __init__(self, channels, use_conv):
        super().__init__()
        self.use_conv = use_conv
        if use_conv:
            self.conv = nn.Conv2d(channels, channels, kernel_size=3, padding=1)
    
    def forward(self, x):
        x = F.interpolate(x, scale_factor=2, mode="nearest")
        if self.use_conv:
            x = self.conv(x)
        return x

class DownSample(nn.Module):
    def __init__(self, channels, use_conv):
        super().__init__()
        self.use_conv = use_conv
        if use_conv:
            self.op = nn.Conv2d(channels, channels, kernel_size=3, padding=1, stride=2)
        else:
            self.op = nn.AvgPool2d(stride=2)
    
    def forward(self, x):
        return self.op(x)
    
class Unet(nn.Module):
    def __init__(self, 
                 in_channels=2,
                 cond_channels=1,
                 model_channels=128,
                 out_channels=2,
                 num_res_blocks=2, 
                 attention_resolutions=(8, 16),
                 dropout=0,
                 channel_mult=(1, 2, 2, 2),
                 conv_resample=True,
                 num_heads=4):
        super().__init__()
        self.in_channels = in_channels
        self.cond_channels = cond_channels
        self.model_channels = model_channels
        self.out_channels = out_channels
        self.num_res_blocks = num_res_blocks
        self.attention_resolutions = attention_resolutions,
        self.dropout = dropout
        self.channel_mult = channel_mult,
        self.conv_resample = conv_resample
        self.num_heads = num_heads
        
        # time embedding
        time_emb_dim = model_channels * 4
        self.time_emb = nn.Sequential(
            nn.Linear(model_channels, time_emb_dim),
            nn.SiLU(),
            nn.Linear(time_emb_dim, time_emb_dim)
        )
        
        # down blocks
        self.down_blocks = nn.ModuleList([
            TimestepEmbedSequential(nn.Conv2d(in_channels, model_channels, kernel_size=3, padding=1))
        ])
        down_block_channels = [model_channels]
        ch = model_channels
        ds = 1
        for level, mult in enumerate(channel_mult):
            for _ in range(num_res_blocks):
                layers = [ResidualBlock(ch, model_channels * mult, time_emb_dim, cond_channels, dropout)]
                ch = model_channels * mult
                if ds in attention_resolutions:
                    layers.append(AttentionBlock(ch, num_heads))
                self.down_blocks.append(TimestepEmbedSequential(*layers))
                down_block_channels.append(ch)
            if level != len(channel_mult) - 1:
                self.down_blocks.append(TimestepEmbedSequential(DownSample(ch, conv_resample)))
                down_block_channels.append(ch)
                ds *= 2
        
        # middle blocks
        self.middle_blocks = TimestepEmbedSequential(
            ResidualBlock(ch, ch, time_emb_dim, cond_channels, dropout),
            AttentionBlock(ch, num_heads),
            ResidualBlock(ch, ch, time_emb_dim, cond_channels, dropout)
        )
        
        # up blocks
        self.up_blocks = nn.ModuleList([])
        for level, mult in enumerate(channel_mult[::-1]):
            for i in range(num_res_blocks + 1):
                layers = [
                    ResidualBlock(ch + down_block_channels.pop(), model_channels * mult, time_emb_dim, cond_channels, dropout)]
                ch = model_channels * mult
                if ds in attention_resolutions:
                    layers.append(AttentionBlock(ch, num_heads))
                if level != len(channel_mult) - 1 and i == num_res_blocks:
                    layers.append(UpSample(ch, conv_resample))
                    ds //= 2
                self.up_blocks.append(TimestepEmbedSequential(*layers))
                
        self.out = nn.Sequential(
            norm_layer(ch),
            nn.SiLU(),
            nn.Conv2d(ch, out_channels, kernel_size=3, padding=1)
        )
    
    def forward(self, x, timesteps, cond_img, mask):
        """
        Apply the model to an input batch.
        :param x: an [N x C x H x W] Tensor of inputs.
        :param timesteps: a 1-D batch of timesteps.
        :param cond_img: a [N x cond_C x H x W] Tensor of conditional images.
        :param mask: a 1-D batch of conditioned/unconditioned.
        :return: an [N x C x ...] Tensor of outputs.
        """
        hs = []
        # time step embedding
        t_emb = self.time_emb(timestep_embedding(timesteps, dim=self.model_channels))
        
        # down step
        h = x
        for module in self.down_blocks:
            if cond_img.shape[2:] != h.shape[2:]:
                cond_img = F.interpolate(cond_img, size=h.shape[2:], mode='nearest')
            h = module(h, t_emb, cond_img, mask)
            hs.append(h)
        # mid stage
        if cond_img.shape[2:] != h.shape[2:]:
            cond_img = F.interpolate(cond_img, size=h.shape[2:], mode='nearest')
        h = self.middle_blocks(h, t_emb, cond_img, mask)

        mid_block_features = h
        
        # up stage
        for module in self.up_blocks:
            h_skip = hs.pop()
            
            if h.shape[2:] != h_skip.shape[2:]:
                h = F.interpolate(h, size=h_skip.shape[2:], mode='nearest')

            if cond_img.shape[2:] != h.shape[2:]:
                cond_img = F.interpolate(cond_img, size=h.shape[2:], mode='nearest')

            cat_in = torch.cat([h, h_skip], dim=1)
            h = module(cat_in, t_emb, cond_img, mask)
        
        return self.out(h), mid_block_features

# %%
# beta schedule
def linear_beta_schedule(timesteps):
    scale = 1000 / timesteps
    beta_start = scale * 0.0001
    beta_end = scale * 0.02
    return torch.linspace(beta_start, beta_end, timesteps, dtype=torch.float64)

def sigmoid_beta_schedule(timesteps):
    betas = torch.linspace(-6, 6, timesteps)
    betas = torch.sigmoid(betas) / (betas.max() - betas.min()) * (0.02 - betas.min()) / 10
    return betas

def cosine_beta_schedule(timesteps, s=0.008):
    steps = timesteps + 1
    x = torch.linspace(0, timesteps, steps, dtype=torch.float64)
    alphas_cumprod = torch.cos(((x / timesteps) + s) / (1 + s) * math.pi * 0.5) ** 2
    alphas_cumprod = alphas_cumprod / alphas_cumprod[0]
    betas = 1 - (alphas_cumprod[1:] / alphas_cumprod[:-1])
    return torch.clip(betas, 0, 0.999)

# %%
class GaussianDiffusion:
    def __init__(
        self,
        timesteps=1000,
        beta_schedule='linear',
    ):
        self.timesteps = timesteps
        
        if beta_schedule == 'linear':
            betas = linear_beta_schedule(timesteps)
        elif beta_schedule == 'cosine':
            betas = cosine_beta_schedule(timesteps)
        elif beta_schedule == 'sigmoid':
            betas = sigmoid_beta_schedule(timesteps)
        else:
            raise ValueError(f'Unknown beta schedule {beta_schedule}')
        
        self.betas = betas
        
        self.alphas = 1. - self.betas
        self.alphas_cumprod = torch.cumprod(self.alphas, axis=0)
        self.alphas_cumprod_prev = F.pad(self.alphas_cumprod[:-1], (1, 0), value=1.)
        
        # calculations for diffusion q(x_t | x_{t-1}) and others
        self.sqrt_alphas_cumprod = torch.sqrt(self.alphas_cumprod)
        self.sqrt_one_minus_alphas_cumprod = torch.sqrt(1.0 - self.alphas_cumprod)
        self.log_one_minus_alphas_cumprod = torch.log(1.0 - self.alphas_cumprod)
        self.sqrt_recip_alphas_cumprod = torch.sqrt(1.0 / self.alphas_cumprod)
        self.sqrt_recipm1_alphas_cumprod = torch.sqrt(1.0 / self.alphas_cumprod - 1)
        
        # calculations for posterior q(x_{t-1} | x_t, x_0)
        self.posterior_variance = (
            self.betas * (1.0 - self.alphas_cumprod_prev) / (1.0 - self.alphas_cumprod)
        )
        self.posterior_log_variance_clipped = torch.log(
            torch.cat([self.posterior_variance[1:2], self.posterior_variance[1:]])
        )
        
        self.posterior_mean_coef1 = (
            self.betas * torch.sqrt(self.alphas_cumprod_prev) / (1.0 - self.alphas_cumprod)
        )
        self.posterior_mean_coef2 = (
            (1.0 - self.alphas_cumprod_prev) * torch.sqrt(self.alphas) / (1.0 - self.alphas_cumprod)
        )
    
    # get the param of given timestep t
    def _extract(self, a, t, x_shape):
        batch_size = t.shape[0]
        out = a.to(t.device).gather(0, t).float()
        out = out.reshape(batch_size, *((1,) * (len(x_shape) - 1)))
        return out
    
    # forward diffusion : q(x_t | x_0)
    def q_sample(self, x_start, t, noise=None):
        if noise is None:
            noise = torch.randn_like(x_start)
        
        sqrt_alphas_cumprod_t = self._extract(self.sqrt_alphas_cumprod, t, x_start.shape)
        sqrt_one_minus_alphas_cumprod_t = self._extract(self.sqrt_one_minus_alphas_cumprod, t, x_start.shape)
        
        return sqrt_alphas_cumprod_t * x_start + sqrt_one_minus_alphas_cumprod_t * noise
    
    # mean and variance of q(x_t | x_0)
    def q_mean_variance(self, x_start, t):
        mean = self._extract(self.sqrt_alphas_cumprod, t, x_start.shape) * x_start
        variance = self._extract(1.0 - self.alphas_cumprod, t, x_start.shape)
        log_variance = self._extract(self.log_one_minus_alphas_cumprod, t, x_start.shape)
        return mean, variance, log_variance
    
    # mean and variance of diffusion posterior: q(x_{t-1} | x_t, x_0)
    def q_posterior_mean_variance(self, x_start, x_t, t):
        posterior_mean = (
            self._extract(self.posterior_mean_coef1, t, x_t.shape) * x_start + self._extract(self.posterior_mean_coef2, t, x_t.shape) * x_t
        )
        posterior_variance = self._extract(self.posterior_variance, t, x_t.shape)
        posterior_log_variance_clipped = self._extract(self.posterior_log_variance_clipped, t, x_t.shape)
        return posterior_mean, posterior_variance, posterior_log_variance_clipped
    
    # compute x_0 from x_t and pred noise: reverse of q_sample
    def predict_start_from_noise(self, x_t, t, noise):
        return (
            self._extract(self.sqrt_recip_alphas_cumprod, t, x_t.shape) * x_t - self._extract(self.sqrt_recipm1_alphas_cumprod, t, x_t.shape) * noise
        )
    
    # compute predicted mean and variance of p(x_{t-1} | x_t) 
    def p_mean_variance(self, model, x_t, t, cond_img, w, clip_denoised=True):
        device = next(model.parameters()).device
        batch_size = x_t.shape[0]
        
        # noise prediction from model
        pred_noise_cond, mid_block_features = model(x_t, t, cond_img, torch.ones(batch_size).int().to(device))
        pred_noise_uncond, mid_block_features = model(x_t, t, cond_img, torch.zeros(batch_size).int().to(device))
        pred_noise = (1 + w) * pred_noise_cond - w * pred_noise_uncond
        
        # get predicted x_0
        x_recon = self.predict_start_from_noise(x_t, t, pred_noise)
        if clip_denoised:
            x_recon = torch.clamp(x_recon, min=-1., max=1.)
        model_mean, posterior_variance, posterior_log_variance = self.q_posterior_mean_variance(x_recon, x_t, t)
        
        return model_mean, posterior_variance, posterior_log_variance
    
    # denoise step: sample x_{t-1} from x_t and pred noise
    @torch.no_grad()
    def p_sample(self, model, x_t, t, cond_img, w, clip_denoised=True):
        # pred mean and variance
        model_mean, _, model_log_variance = self.p_mean_variance(model, x_t, t, cond_img, w, clip_denoised=clip_denoised)
        
        noise = torch.randn_like(x_t)
        # no noise when t = 0 
        nonzero_mask = ((t != 0).float().view(-1, *([1] * (len(x_t.shape) - 1))))
        # compute x_{t-1}
        pred_img = model_mean + nonzero_mask * (0.5 * model_log_variance).exp() * noise
        return pred_img
    
    # denoise : reverse diffusion
    @torch.no_grad()
    def p_sample_loop(self, model, shape, cond_img, w=2, clip_denoised=True):
        batch_size = shape[0]
        device = next(model.parameters()).device
        
        # start from pure noise
        img = torch.randn(shape, device=device)
        imgs = []
        for i in tqdm(reversed(range(0, self.timesteps)), desc='sampling loop time step', total=self.timesteps):
            img = self.p_sample(model, img, torch.full((batch_size,), i, device=device, dtype=torch.long), cond_img, w, clip_denoised)
            imgs.append(img.cpu().numpy())
        return imgs
    
    # sample new images
    @torch.no_grad
    def sample(self, model, image_size, cond_img, batch_size=8, channels=3, w=2, clip_denoised=True):
        return self.p_sample_loop(model, (batch_size, channels, image_size, image_size), cond_img, w, clip_denoised)
    
    # use ddim to sample
    @torch.no_grad()
    def ddim_sample(
        self,
        model,
        image_size,
        cond_img,
        batch_size=8,
        channels=3,
        ddim_timesteps=50,
        w=2,
        ddim_discr_method="uniform",
        ddim_eta=0.0,
        clip_denoised=True):
        
        # make ddim timestep sequence
        if ddim_discr_method == 'uniform':
            c = self.timesteps // ddim_timesteps
            ddim_timestep_seq = np.asarray(list(range(0, self.timesteps, c)))
        elif ddim_discr_method == 'quad':
            ddim_timestep_seq = (
                (np.linspace(0, np.sqrt(self.timesteps * .8), ddim_timesteps)) ** 2
            ).astype(int)
        else:
            raise NotImplementedError(f'There is no ddim discretization method called "{ddim_discr_method}"')
        # add one to get the final alpha values right (the ones from first scale to data during sampling)
        ddim_timestep_seq = ddim_timestep_seq + 1
        # previous sequence
        ddim_timestep_prev_seq = np.append(np.array([0]), ddim_timestep_seq[:-1])
        
        device = next(model.parameters()).device
        
        # start from pure noise (for each example in the batch)
        sample_img = torch.randn((batch_size, channels, image_size, image_size), device=device)
        seq_img = [sample_img.cpu().numpy()]   
        
        for i in tqdm(reversed(range(0, ddim_timesteps)), desc='sampling loop time step', total=ddim_timesteps):
            t = torch.full((batch_size,), ddim_timestep_seq[i], device=device, dtype=torch.long)
            prev_t = torch.full((batch_size,), ddim_timestep_prev_seq[i], device=device, dtype=torch.long)
            
            # 1. get current and previous alpha_cumprod
            alpha_cumprod_t = self._extract(self.alphas_cumprod, t, sample_img.shape)
            alpha_cumprod_t_prev = self._extract(self.alphas_cumprod, prev_t, sample_img.shape)
    
            # 2. predict noise using model
            pred_noise_cond, mid_block_features = model(sample_img, t, cond_img, torch.ones(batch_size).int().cuda())
            pred_noise_uncond, mid_block_features = model(sample_img, t, cond_img, torch.zeros(batch_size).int().cuda())
            pred_noise = (1+w)*pred_noise_cond - w*pred_noise_uncond
            
            # 3. get the predicted x_0
            pred_x0 = (sample_img - torch.sqrt((1. - alpha_cumprod_t)) * pred_noise) / torch.sqrt(alpha_cumprod_t)
            if clip_denoised:
                pred_x0 = torch.clamp(pred_x0, min=-1., max=1.)
            
            # 4. compute variance: "sigma_t(η)" -> see formula (16)
            # σ_t = sqrt((1 − α_t−1)/(1 − α_t)) * sqrt(1 − α_t/α_t−1)
            sigmas_t = ddim_eta * torch.sqrt(
                (1 - alpha_cumprod_t_prev) / (1 - alpha_cumprod_t) * (1 - alpha_cumprod_t / alpha_cumprod_t_prev))
            
            # 5. compute "direction pointing to x_t" of formula (12)
            pred_dir_xt = torch.sqrt(1 - alpha_cumprod_t_prev - sigmas_t**2) * pred_noise
            
            # 6. compute x_{t-1} of formula (12)
            x_prev = torch.sqrt(alpha_cumprod_t_prev) * pred_x0 + pred_dir_xt + sigmas_t * torch.randn_like(sample_img)

            sample_img = x_prev

        return sample_img.cpu().numpy()
    
    # compute train losses
    def train_losses(self, model, x_start, t, cond_img, mask_c):
        # generate random noise
        noise = torch.randn_like(x_start)
        # get x_t
        x_noisy = self.q_sample(x_start, t, noise=noise)
        predicted_noise, mid_block_features = model(x_noisy, t, cond_img, mask_c)
        loss = F.mse_loss(noise, predicted_noise)
        return loss, predicted_noise, mid_block_features

# %% [markdown]
# ## Dataset

# %%
class ConditionalImageDataset(Dataset):
    def __init__(self, data_dir, transform=None, conditional_offset=5):
        self.data_dir = data_dir
        self.transform = transform
        self.conditional_offset = conditional_offset
        self.regression_csv_path = os.path.join(data_dir, "regression_params.csv")
        self.cond_images = []
        self.target_images = []
        self.reg_data = None
        self._load_data()

    def _load_data(self):
        files = sorted([os.path.join(self.data_dir, f) for f in os.listdir(self.data_dir) if f.endswith('.mpy')])
        for file in files:
            with open(file, 'rb') as f:
                images = pickle.load(f)
                if isinstance(images, list):
                    images = np.array(images)
                    
                for img_idx in range(len(images) - self.conditional_offset):
                    self.cond_images.append(images[img_idx])
                    self.target_images.append(images[img_idx + self.conditional_offset])
                    
        headers = ["p_h", "a", "c_1", "c_2"]
        self.reg_data = pd.read_csv(self.regression_csv_path, names=headers, index_col=0)

    def __len__(self):
        return len(self.cond_images)

    def __getitem__(self, idx):
        # collection_idx, image_idx = self._get_indices(idx)
        cond_image = self.cond_images[idx]
        image = self.target_images[idx]
        reg_params = self.reg_data.loc[idx // 15].to_numpy()

        if self.transform:
            image = self.transform(image)
            cond_image = self.transform(cond_image)

        return image, cond_image, reg_params

# %% [markdown]
# ## Regression Model

# %%
# Define the MLP regression model
class MLPRegressor(nn.Module):
    def __init__(self, input_channels, feature_size, hidden_sizes, output_size):
        super(MLPRegressor, self).__init__()
        input_size = input_channels * feature_size * feature_size
        self.fc_layers = nn.ModuleList()
        
        # Define the MLP layers
        in_size = input_size
        for hidden_size in hidden_sizes:
            self.fc_layers.append(nn.Linear(in_size, hidden_size))
            self.fc_layers.append(nn.ReLU())
            in_size = hidden_size
        self.fc_layers.append(nn.Linear(in_size, output_size))

    def forward(self, x):
        # Flatten the input
        x = x.view(x.size(0), -1)
        
        # Forward pass through the layers
        for layer in self.fc_layers:
            x = layer(x)
        
        return x

# %%
# Parameters
input_channels = 192  # Number of input channels
feature_size = 16     # Feature size (16x16)
hidden_sizes = [1024, 512, 256]  # Example hidden layer sizes
output_size = 4  # Number of predicted values

# Instantiate the model, loss function, and optimizer
reg_model = MLPRegressor(input_channels, feature_size, hidden_sizes, output_size)
reg_model.to(device)

# Define the loss function and optimizer
reg_criterion = nn.MSELoss()
reg_optimizer = torch.optim.Adam(reg_model.parameters(), lr=0.001)

# %%
def train_regressor(model, train_data, optimizer, criterion, epochs=10):
    for epoch in range(epochs):
        model.train()
        optimizer.zero_grad()

        input_features, reg_params = train_data
        
        output = model(input_features)
        loss = criterion(output, reg_params)

        print(f'Regression Training - Epoch {epoch+1}/{epochs}, Loss: {loss.item()}')
        return loss

# %% [markdown]
# ## Regression Guided Diffusion Training

# %%
batch_size = 32
timesteps = 500

transform = transforms.Compose([
    transforms.ToTensor(),
    # transforms.Normalize(mean=[0.5], std=[0.5]),
    transforms.Resize(64)
])

DATA_DIR = os.path.join(VOL_DIR, "data/simulated_bin_frames")
RESULT_DIR = os.path.join(VOL_DIR, "results/")
CKPT_DIR = os.path.join(VOL_DIR, "results/ckpts") 

# MNIST DATA
dataset = ConditionalImageDataset(DATA_DIR, transform=transform)

# Split dataset into training and testing
train_size = int(0.9 * len(dataset))
test_size = len(dataset) - train_size
train_dataset, test_dataset = torch.utils.data.random_split(dataset, [train_size, test_size])

# Create DataLoader
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=batch_size, shuffle=True)

device = "cuda" if torch.cuda.is_available() else "cpu"
diff_model = Unet(
    in_channels=1,
    cond_channels=1,
    model_channels=96,
    out_channels=1,
    channel_mult=(1, 2, 2),
    attention_resolutions=[],
)
diff_model.to(device)
# Out:
# Unet(
#   (time_emb): Sequential(
#     (0): Linear(in_features=96, out_features=384, bias=True)
#     (1): SiLU()
#     (2): Linear(in_features=384, out_features=384, bias=True)
#   )
#   (down_blocks): ModuleList(
#     (0): TimestepEmbedSequential(
#       (0): Conv2d(1, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (1-2): 2 x TimestepEmbedSequential(
#       (0): ResidualBlock(
#         (conv1): Sequential(
#           (0): GroupNorm(32, 96, eps=1e-05, affine=True)
#           (1): SiLU()
#           (2): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#         (time_emb): Sequential(
#           (0): SiLU()
#           (1): Linear(in_features=384, out_features=96, bias=True)
#         )
#         (cond_conv): Sequential(
#           (0): Conv2d(1, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): SiLU()
#         )
#         (conv2): Sequential(
#           (0): GroupNorm(32, 96, eps=1e-05, affine=True)
#           (1): SiLU()
#           (2): Dropout(p=0, inplace=False)
#           (3): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#         (shortcut): Identity()
#       )
#     )
#     (3): TimestepEmbedSequential(
#       (0): DownSample(
#         (op): Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       )
#     )
#     (4): TimestepEmbedSequential(
#       (0): ResidualBlock(
#         (conv1): Sequential(
#           (0): GroupNorm(32, 96, eps=1e-05, affine=True)
#           (1): SiLU()
#           (2): Conv2d(96, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#         (time_emb): Sequential(
#           (0): SiLU()
#           (1): Linear(in_features=384, out_features=192, bias=True)
#         )
#         (cond_conv): Sequential(
#           (0): Conv2d(1, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): SiLU()
#         )
#         (conv2): Sequential(
#           (0): GroupNorm(32, 192, eps=1e-05, affine=True)
#           (1): SiLU()
#           (2): Dropout(p=0, inplace=False)
#           (3): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#         (shortcut): Conv2d(96, 192, kernel_size=(1, 1), stride=(1, 1))
#       )
#     )
#     (5): TimestepEmbedSequential(
#       (0): ResidualBlock(
#         (conv1): Sequential(
#           (0): GroupNorm(32, 192, eps=1e-05, affine=True)
#           (1): SiLU()
#           (2): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#         (time_emb): Sequential(
#           (0): SiLU()
#           (1): Linear(in_features=384, out_features=192, bias=True)
#         )
#         (cond_conv): Sequential(
#           (0): Conv2d(1, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): SiLU()
#         )
#         (conv2): Sequential(
#           (0): GroupNorm(32, 192, eps=1e-05, affine=True)
#           (1): SiLU()
#           (2): Dropout(p=0, inplace=False)
#           (3): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#         (shortcut): Identity()
#       )
#     )
#     (6): TimestepEmbedSequential(
#       (0): DownSample(
#         (op): Conv2d(192, 192, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       )
#     )
#     (7-8): 2 x TimestepEmbedSequential(
#       (0): ResidualBlock(
#         (conv1): Sequential(
#           (0): GroupNorm(32, 192, eps=1e-05, affine=True)
#           (1): SiLU()
#           (2): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#         (time_emb): Sequential(
#           (0): SiLU()
#           (1): Linear(in_features=384, out_features=192, bias=True)
#         )
#         (cond_conv): Sequential(
#           (0): Conv2d(1, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): SiLU()
#         )
#         (conv2): Sequential(
#           (0): GroupNorm(32, 192, eps=1e-05, affine=True)
#           (1): SiLU()
#           (2): Dropout(p=0, inplace=False)
#           (3): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#         (shortcut): Identity()
#       )
#     )
#   )
#   (middle_blocks): TimestepEmbedSequential(
#     (0): ResidualBlock(
#       (conv1): Sequential(
#         (0): GroupNorm(32, 192, eps=1e-05, affine=True)
#         (1): SiLU()
#         (2): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#       (time_emb): Sequential(
#         (0): SiLU()
#         (1): Linear(in_features=384, out_features=192, bias=True)
#       )
#       (cond_conv): Sequential(
#         (0): Conv2d(1, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): SiLU()
#       )
#       (conv2): Sequential(
#         (0): GroupNorm(32, 192, eps=1e-05, affine=True)
#         (1): SiLU()
#         (2): Dropout(p=0, inplace=False)
#         (3): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#       (shortcut): Identity()
#     )
#     (1): AttentionBlock(
#       (norm): GroupNorm(32, 192, eps=1e-05, affine=True)
#       (qkv): Conv2d(192, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (proj): Conv2d(192, 192, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (2): ResidualBlock(
#       (conv1): Sequential(
#         (0): GroupNorm(32, 192, eps=1e-05, affine=True)
#         (1): SiLU()
#         (2): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#       (time_emb): Sequential(
#         (0): SiLU()
#         (1): Linear(in_features=384, out_features=192, bias=True)
#       )
#       (cond_conv): Sequential(
#         (0): Conv2d(1, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): SiLU()
#       )
#       (conv2): Sequential(
#         (0): GroupNorm(32, 192, eps=1e-05, affine=True)
#         (1): SiLU()
#         (2): Dropout(p=0, inplace=False)
#         (3): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#       (shortcut): Identity()
#     )
#   )
#   (up_blocks): ModuleList(
#     (0-1): 2 x TimestepEmbedSequential(
#       (0): ResidualBlock(
#         (conv1): Sequential(
#           (0): GroupNorm(32, 384, eps=1e-05, affine=True)
#           (1): SiLU()
#           (2): Conv2d(384, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#         (time_emb): Sequential(
#           (0): SiLU()
#           (1): Linear(in_features=384, out_features=192, bias=True)
#         )
#         (cond_conv): Sequential(
#           (0): Conv2d(1, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): SiLU()
#         )
#         (conv2): Sequential(
#           (0): GroupNorm(32, 192, eps=1e-05, affine=True)
#           (1): SiLU()
#           (2): Dropout(p=0, inplace=False)
#           (3): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#         (shortcut): Conv2d(384, 192, kernel_size=(1, 1), stride=(1, 1))
#       )
#     )
#     (2): TimestepEmbedSequential(
#       (0): ResidualBlock(
#         (conv1): Sequential(
#           (0): GroupNorm(32, 384, eps=1e-05, affine=True)
#           (1): SiLU()
#           (2): Conv2d(384, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#         (time_emb): Sequential(
#           (0): SiLU()
#           (1): Linear(in_features=384, out_features=192, bias=True)
#         )
#         (cond_conv): Sequential(
#           (0): Conv2d(1, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): SiLU()
#         )
#         (conv2): Sequential(
#           (0): GroupNorm(32, 192, eps=1e-05, affine=True)
#           (1): SiLU()
#           (2): Dropout(p=0, inplace=False)
#           (3): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#         (shortcut): Conv2d(384, 192, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (1): UpSample(
#         (conv): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#     )
#     (3-4): 2 x TimestepEmbedSequential(
#       (0): ResidualBlock(
#         (conv1): Sequential(
#           (0): GroupNorm(32, 384, eps=1e-05, affine=True)
#           (1): SiLU()
#           (2): Conv2d(384, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#         (time_emb): Sequential(
#           (0): SiLU()
#           (1): Linear(in_features=384, out_features=192, bias=True)
#         )
#         (cond_conv): Sequential(
#           (0): Conv2d(1, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): SiLU()
#         )
#         (conv2): Sequential(
#           (0): GroupNorm(32, 192, eps=1e-05, affine=True)
#           (1): SiLU()
#           (2): Dropout(p=0, inplace=False)
#           (3): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#         (shortcut): Conv2d(384, 192, kernel_size=(1, 1), stride=(1, 1))
#       )
#     )
#     (5): TimestepEmbedSequential(
#       (0): ResidualBlock(
#         (conv1): Sequential(
#           (0): GroupNorm(32, 288, eps=1e-05, affine=True)
#           (1): SiLU()
#           (2): Conv2d(288, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#         (time_emb): Sequential(
#           (0): SiLU()
#           (1): Linear(in_features=384, out_features=192, bias=True)
#         )
#         (cond_conv): Sequential(
#           (0): Conv2d(1, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): SiLU()
#         )
#         (conv2): Sequential(
#           (0): GroupNorm(32, 192, eps=1e-05, affine=True)
#           (1): SiLU()
#           (2): Dropout(p=0, inplace=False)
#           (3): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#         (shortcut): Conv2d(288, 192, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (1): UpSample(
#         (conv): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#     )
#     (6): TimestepEmbedSequential(
#       (0): ResidualBlock(
#         (conv1): Sequential(
#           (0): GroupNorm(32, 288, eps=1e-05, affine=True)
#           (1): SiLU()
#           (2): Conv2d(288, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#         (time_emb): Sequential(
#           (0): SiLU()
#           (1): Linear(in_features=384, out_features=96, bias=True)
#         )
#         (cond_conv): Sequential(
#           (0): Conv2d(1, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): SiLU()
#         )
#         (conv2): Sequential(
#           (0): GroupNorm(32, 96, eps=1e-05, affine=True)
#           (1): SiLU()
#           (2): Dropout(p=0, inplace=False)
#           (3): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#         (shortcut): Conv2d(288, 96, kernel_size=(1, 1), stride=(1, 1))
#       )
#     )
#     (7-8): 2 x TimestepEmbedSequential(
#       (0): ResidualBlock(
#         (conv1): Sequential(
#           (0): GroupNorm(32, 192, eps=1e-05, affine=True)
#           (1): SiLU()
#           (2): Conv2d(192, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#         (time_emb): Sequential(
#           (0): SiLU()
#           (1): Linear(in_features=384, out_features=96, bias=True)
#         )
#         (cond_conv): Sequential(
#           (0): Conv2d(1, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): SiLU()
#         )
#         (conv2): Sequential(
#           (0): GroupNorm(32, 96, eps=1e-05, affine=True)
#           (1): SiLU()
#           (2): Dropout(p=0, inplace=False)
#           (3): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#         (shortcut): Conv2d(192, 96, kernel_size=(1, 1), stride=(1, 1))
#       )
#     )
#   )
#   (out): Sequential(
#     (0): GroupNorm(32, 96, eps=1e-05, affine=True)
#     (1): SiLU()
#     (2): Conv2d(96, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   )
# )

# %%
image = next(iter(train_loader))[0][0].squeeze()
conditional = next(iter(train_loader))[1][0].squeeze()

x_start = image.float()

gaussian_diffusion = GaussianDiffusion(timesteps=500, beta_schedule='linear')

plt.figure(figsize=(16, 5))
for idx, t in enumerate([0, 100, 300, 400, 499]):
    x_noisy = gaussian_diffusion.q_sample(x_start.to(device), t=torch.tensor([t]).to(device))
    noisy_image = (x_noisy.squeeze() + 1) * 127.5
    if idx==0:
        noisy_image = (x_start.squeeze() + 1) * 127.5
    noisy_image = noisy_image.cpu().numpy().astype(np.uint8)
    plt.subplot(1, 5, 1 + idx)
    plt.imshow(noisy_image, cmap='gray')
    plt.axis("off")
    plt.title(f"t={t}")

# %%
epochs = 20
p_uncound = 0.2
len_data = len(train_loader)
time_end = time.time()
timesteps=500

diff_optimizer = torch.optim.Adam(diff_model.parameters(), lr=1e-4)
gaussian_diffusion = GaussianDiffusion(timesteps=500, beta_schedule='linear')

for epoch in range(epochs):
    for step, (images, cond_images, reg_params) in enumerate(train_loader):  
        images = images.float().to(device)
        cond_images = cond_images.float().to(device)
        reg_params = reg_params.float().to(device)
        
        time_start = time_end
        
        diff_optimizer.zero_grad()
        
        batch_size = images.shape[0]
        images = images.to(device).float()
        cond_images = cond_images.to(device).float()
        
        # random generate mask
        z_uncound = torch.rand(batch_size)
        batch_mask = (z_uncound>p_uncound).int().to(device)
        
        # sample t uniformally for every example in the batch
        t = torch.randint(0, timesteps, (batch_size,), device=device).long()
        loss, outputs, mid_block_features = gaussian_diffusion.train_losses(diff_model, images, t, cond_images, batch_mask)

        mid_block_features = mid_block_features.to(device)

        # train regression
        reg_input = (mid_block_features, reg_params)
        reg_loss = train_regressor(reg_model, reg_input, reg_optimizer, reg_criterion, epochs=1)

        total_loss = loss + reg_loss
        
        if step % 100 == 0:
            time_end = time.time()
            print("Epoch{}/{}\t  Step{}/{}\t Loss {:.4f}\t Time {:.2f}".format(epoch+1, epochs, step+1, len_data, loss.item(), time_end-time_start))
            
        total_loss.backward()
        diff_optimizer.step()
        reg_optimizer.step()
# Out:
# Regression Training - Epoch 1/1, Loss: 0.02790156938135624
# Epoch1/20	  Step1/22	 Loss 1.1638	 Time 0.54
# Regression Training - Epoch 1/1, Loss: 65.53062438964844
# Regression Training - Epoch 1/1, Loss: 0.012308746576309204
# Regression Training - Epoch 1/1, Loss: 0.5773333311080933
# Regression Training - Epoch 1/1, Loss: 0.19739696383476257
# Regression Training - Epoch 1/1, Loss: 0.9236261248588562
# Regression Training - Epoch 1/1, Loss: 0.21648842096328735
# Regression Training - Epoch 1/1, Loss: 0.17069971561431885
# Regression Training - Epoch 1/1, Loss: 0.08838748931884766
# Regression Training - Epoch 1/1, Loss: 0.07807612419128418
# Regression Training - Epoch 1/1, Loss: 0.04478113725781441
# Regression Training - Epoch 1/1, Loss: 0.06997108459472656
# Regression Training - Epoch 1/1, Loss: 0.01695956662297249
# Regression Training - Epoch 1/1, Loss: 0.019942935556173325
# Regression Training - Epoch 1/1, Loss: 0.02929518185555935
# Regression Training - Epoch 1/1, Loss: 0.018831823021173477
# Regression Training - Epoch 1/1, Loss: 0.006981286220252514
# Regression Training - Epoch 1/1, Loss: 0.02014186978340149
# Regression Training - Epoch 1/1, Loss: 0.015383346006274223
# Regression Training - Epoch 1/1, Loss: 0.009229901246726513
# Regression Training - Epoch 1/1, Loss: 0.011313604190945625
# Regression Training - Epoch 1/1, Loss: 0.010740666650235653
# Regression Training - Epoch 1/1, Loss: 0.009626687504351139
# Epoch2/20	  Step1/22	 Loss 0.0413	 Time 9.94
# Regression Training - Epoch 1/1, Loss: 0.009549291804432869
# Regression Training - Epoch 1/1, Loss: 0.005586511455476284
# Regression Training - Epoch 1/1, Loss: 0.00770011730492115
# Regression Training - Epoch 1/1, Loss: 0.008299403823912144
# Regression Training - Epoch 1/1, Loss: 0.007509848102927208
# Regression Training - Epoch 1/1, Loss: 0.006213568150997162
# Regression Training - Epoch 1/1, Loss: 0.006995271425694227
# Regression Training - Epoch 1/1, Loss: 0.006519674323499203
# Regression Training - Epoch 1/1, Loss: 0.0057396236807107925
# Regression Training - Epoch 1/1, Loss: 0.006206556688994169
# Regression Training - Epoch 1/1, Loss: 0.005900589749217033
# Regression Training - Epoch 1/1, Loss: 0.005436629056930542
# Regression Training - Epoch 1/1, Loss: 0.004550720565021038
# Regression Training - Epoch 1/1, Loss: 0.005715550389140844
# Regression Training - Epoch 1/1, Loss: 0.004502333700656891
# Regression Training - Epoch 1/1, Loss: 0.005658452399075031
# Regression Training - Epoch 1/1, Loss: 0.004204779863357544
# Regression Training - Epoch 1/1, Loss: 0.004555259831249714
# Regression Training - Epoch 1/1, Loss: 0.004231945611536503
# Regression Training - Epoch 1/1, Loss: 0.005667190067470074
# Regression Training - Epoch 1/1, Loss: 0.0061265332624316216
# Regression Training - Epoch 1/1, Loss: 0.004457286559045315
# Epoch3/20	  Step1/22	 Loss 0.0234	 Time 9.70
# Regression Training - Epoch 1/1, Loss: 0.005767381750047207
# Regression Training - Epoch 1/1, Loss: 0.00489948783069849
# Regression Training - Epoch 1/1, Loss: 0.004759321454912424
# Regression Training - Epoch 1/1, Loss: 0.005212943535298109
# Regression Training - Epoch 1/1, Loss: 0.0047945743426680565
# Regression Training - Epoch 1/1, Loss: 0.005935225635766983
# Regression Training - Epoch 1/1, Loss: 0.004286505747586489
# Regression Training - Epoch 1/1, Loss: 0.0043961768969893456
# Regression Training - Epoch 1/1, Loss: 0.004633400589227676
# Regression Training - Epoch 1/1, Loss: 0.0059857554733753204
# Regression Training - Epoch 1/1, Loss: 0.004955913871526718
# Regression Training - Epoch 1/1, Loss: 0.004345115274190903
# Regression Training - Epoch 1/1, Loss: 0.004249345511198044
# Regression Training - Epoch 1/1, Loss: 0.004998599179089069
# Regression Training - Epoch 1/1, Loss: 0.004215644206851721
# Regression Training - Epoch 1/1, Loss: 0.00472709396854043
# Regression Training - Epoch 1/1, Loss: 0.004853488877415657
# Regression Training - Epoch 1/1, Loss: 0.00390651123598218
# Regression Training - Epoch 1/1, Loss: 0.005358231719583273
# Regression Training - Epoch 1/1, Loss: 0.005071503110229969
# Regression Training - Epoch 1/1, Loss: 0.0035412348806858063
# Regression Training - Epoch 1/1, Loss: 0.004999077878892422
# Epoch4/20	  Step1/22	 Loss 0.0174	 Time 9.70
# Regression Training - Epoch 1/1, Loss: 0.004428318701684475
# Regression Training - Epoch 1/1, Loss: 0.004585249815136194
# Regression Training - Epoch 1/1, Loss: 0.00400673458352685
# Regression Training - Epoch 1/1, Loss: 0.004291487857699394
# Regression Training - Epoch 1/1, Loss: 0.004506119526922703
# Regression Training - Epoch 1/1, Loss: 0.0039366441778838634
# Regression Training - Epoch 1/1, Loss: 0.005031657870858908
# Regression Training - Epoch 1/1, Loss: 0.003688664175570011
# Regression Training - Epoch 1/1, Loss: 0.004328304436057806
# Regression Training - Epoch 1/1, Loss: 0.0042014699429273605
# Regression Training - Epoch 1/1, Loss: 0.004542730748653412
# Regression Training - Epoch 1/1, Loss: 0.0034494753926992416
# Regression Training - Epoch 1/1, Loss: 0.004956722725182772
# Regression Training - Epoch 1/1, Loss: 0.004256985150277615
# Regression Training - Epoch 1/1, Loss: 0.004151114262640476
# Regression Training - Epoch 1/1, Loss: 0.0046212696470320225
# Regression Training - Epoch 1/1, Loss: 0.003633467946201563
# Regression Training - Epoch 1/1, Loss: 0.00418642396107316
# Regression Training - Epoch 1/1, Loss: 0.004693157970905304
# Regression Training - Epoch 1/1, Loss: 0.005031939130276442
# Regression Training - Epoch 1/1, Loss: 0.005827959626913071
# Regression Training - Epoch 1/1, Loss: 0.004899367690086365
# Epoch5/20	  Step1/22	 Loss 0.0220	 Time 9.70
# Regression Training - Epoch 1/1, Loss: 0.00393130024895072
# Regression Training - Epoch 1/1, Loss: 0.00439952127635479
# Regression Training - Epoch 1/1, Loss: 0.004740170203149319
# Regression Training - Epoch 1/1, Loss: 0.004052175208926201
# Regression Training - Epoch 1/1, Loss: 0.003676213091239333
# Regression Training - Epoch 1/1, Loss: 0.004167071543633938
# Regression Training - Epoch 1/1, Loss: 0.004851303994655609
# Regression Training - Epoch 1/1, Loss: 0.005435227416455746
# Regression Training - Epoch 1/1, Loss: 0.0033769337460398674
# Regression Training - Epoch 1/1, Loss: 0.004637657664716244
# Regression Training - Epoch 1/1, Loss: 0.004222795832902193
# Regression Training - Epoch 1/1, Loss: 0.004703083075582981
# Regression Training - Epoch 1/1, Loss: 0.004938297905027866
# Regression Training - Epoch 1/1, Loss: 0.003587324172258377
# Regression Training - Epoch 1/1, Loss: 0.004311702214181423
# Regression Training - Epoch 1/1, Loss: 0.004844422917813063
# Regression Training - Epoch 1/1, Loss: 0.00388654344715178
# Regression Training - Epoch 1/1, Loss: 0.004722895100712776
# Regression Training - Epoch 1/1, Loss: 0.004614048637449741
# Regression Training - Epoch 1/1, Loss: 0.004465069621801376
# Regression Training - Epoch 1/1, Loss: 0.006804274395108223
# Regression Training - Epoch 1/1, Loss: 0.004153819754719734
# Epoch6/20	  Step1/22	 Loss 0.0108	 Time 9.69
# Regression Training - Epoch 1/1, Loss: 0.0047537717036902905
# Regression Training - Epoch 1/1, Loss: 0.005070580169558525
# Regression Training - Epoch 1/1, Loss: 0.0045983572490513325
# Regression Training - Epoch 1/1, Loss: 0.0045466311275959015
# Regression Training - Epoch 1/1, Loss: 0.0054264552891254425
# Regression Training - Epoch 1/1, Loss: 0.004657680168747902
# Regression Training - Epoch 1/1, Loss: 0.005295521579682827
# Regression Training - Epoch 1/1, Loss: 0.005143948830664158
# Regression Training - Epoch 1/1, Loss: 0.004156746901571751
# Regression Training - Epoch 1/1, Loss: 0.0031160784419625998
# Regression Training - Epoch 1/1, Loss: 0.004464941099286079
# Regression Training - Epoch 1/1, Loss: 0.004154380410909653
# Regression Training - Epoch 1/1, Loss: 0.0034092292189598083
# Regression Training - Epoch 1/1, Loss: 0.004192870110273361
# Regression Training - Epoch 1/1, Loss: 0.003539379918947816
# Regression Training - Epoch 1/1, Loss: 0.0031589469872415066
# Regression Training - Epoch 1/1, Loss: 0.004467939026653767
# Regression Training - Epoch 1/1, Loss: 0.003984074108302593
# Regression Training - Epoch 1/1, Loss: 0.004299773834645748
# Regression Training - Epoch 1/1, Loss: 0.004731412045657635
# Regression Training - Epoch 1/1, Loss: 0.00378156965598464
# Regression Training - Epoch 1/1, Loss: 0.0041965823620557785
# Epoch7/20	  Step1/22	 Loss 0.0087	 Time 9.70
# Regression Training - Epoch 1/1, Loss: 0.0037581981159746647
# Regression Training - Epoch 1/1, Loss: 0.004493861459195614
# Regression Training - Epoch 1/1, Loss: 0.004134989809244871
# Regression Training - Epoch 1/1, Loss: 0.003052799729630351
# Regression Training - Epoch 1/1, Loss: 0.0037550816778093576
# Regression Training - Epoch 1/1, Loss: 0.004805826116353273
# Regression Training - Epoch 1/1, Loss: 0.005441134795546532
# Regression Training - Epoch 1/1, Loss: 0.004212715197354555
# Regression Training - Epoch 1/1, Loss: 0.0037229019217193127
# Regression Training - Epoch 1/1, Loss: 0.004396461416035891
# Regression Training - Epoch 1/1, Loss: 0.004772246815264225
# Regression Training - Epoch 1/1, Loss: 0.005516221281141043
# Regression Training - Epoch 1/1, Loss: 0.005017856135964394
# Regression Training - Epoch 1/1, Loss: 0.005052541382610798
# Regression Training - Epoch 1/1, Loss: 0.004059504717588425
# Regression Training - Epoch 1/1, Loss: 0.00373886339366436
# Regression Training - Epoch 1/1, Loss: 0.00427097175270319
# Regression Training - Epoch 1/1, Loss: 0.004545080009847879
# Regression Training - Epoch 1/1, Loss: 0.0036469395272433758
# Regression Training - Epoch 1/1, Loss: 0.0036824182607233524
# Regression Training - Epoch 1/1, Loss: 0.003991257399320602
# Regression Training - Epoch 1/1, Loss: 0.0038584284484386444
# Epoch8/20	  Step1/22	 Loss 0.0090	 Time 9.70
# Regression Training - Epoch 1/1, Loss: 0.0038709710352122784
# Regression Training - Epoch 1/1, Loss: 0.004686171188950539
# Regression Training - Epoch 1/1, Loss: 0.004524595104157925
# Regression Training - Epoch 1/1, Loss: 0.0034368601627647877
# Regression Training - Epoch 1/1, Loss: 0.004140639211982489
# Regression Training - Epoch 1/1, Loss: 0.0038696909323334694
# Regression Training - Epoch 1/1, Loss: 0.004379843361675739
# Regression Training - Epoch 1/1, Loss: 0.004232133738696575
# Regression Training - Epoch 1/1, Loss: 0.004397624637931585
# Regression Training - Epoch 1/1, Loss: 0.003787284716963768
# Regression Training - Epoch 1/1, Loss: 0.0037800022400915623
# Regression Training - Epoch 1/1, Loss: 0.0032109213061630726
# Regression Training - Epoch 1/1, Loss: 0.003164355643093586
# Regression Training - Epoch 1/1, Loss: 0.003079719841480255
# Regression Training - Epoch 1/1, Loss: 0.004710097331553698
# Regression Training - Epoch 1/1, Loss: 0.004329513758420944
# Regression Training - Epoch 1/1, Loss: 0.00497602391988039
# Regression Training - Epoch 1/1, Loss: 0.004574189893901348
# Regression Training - Epoch 1/1, Loss: 0.0042248978279531
# Regression Training - Epoch 1/1, Loss: 0.004264172166585922
# Regression Training - Epoch 1/1, Loss: 0.004650574177503586
# Regression Training - Epoch 1/1, Loss: 0.004229649435728788
# Epoch9/20	  Step1/22	 Loss 0.0085	 Time 9.71
# Regression Training - Epoch 1/1, Loss: 0.0064107561483979225
# Regression Training - Epoch 1/1, Loss: 0.006605666596442461
# Regression Training - Epoch 1/1, Loss: 0.003134567756205797
# Regression Training - Epoch 1/1, Loss: 0.0038350154645740986
# Regression Training - Epoch 1/1, Loss: 0.004510808270424604
# Regression Training - Epoch 1/1, Loss: 0.005373000167310238
# Regression Training - Epoch 1/1, Loss: 0.005342815537005663
# Regression Training - Epoch 1/1, Loss: 0.0033713660668581724
# Regression Training - Epoch 1/1, Loss: 0.00442640483379364
# Regression Training - Epoch 1/1, Loss: 0.004710385110229254
# Regression Training - Epoch 1/1, Loss: 0.004274379462003708
# Regression Training - Epoch 1/1, Loss: 0.005389321595430374
# Regression Training - Epoch 1/1, Loss: 0.005213414318859577
# Regression Training - Epoch 1/1, Loss: 0.004295152612030506
# Regression Training - Epoch 1/1, Loss: 0.0038307085633277893
# Regression Training - Epoch 1/1, Loss: 0.005204489920288324
# Regression Training - Epoch 1/1, Loss: 0.004543625749647617
# Regression Training - Epoch 1/1, Loss: 0.0036828683223575354
# Regression Training - Epoch 1/1, Loss: 0.00389992818236351
# Regression Training - Epoch 1/1, Loss: 0.003270234912633896
# Regression Training - Epoch 1/1, Loss: 0.0023755021393299103
# Regression Training - Epoch 1/1, Loss: 0.004341171123087406
# Epoch10/20	  Step1/22	 Loss 0.0139	 Time 9.71
# Regression Training - Epoch 1/1, Loss: 0.004237548913806677
# Regression Training - Epoch 1/1, Loss: 0.004871861077845097
# Regression Training - Epoch 1/1, Loss: 0.003720963839441538
# Regression Training - Epoch 1/1, Loss: 0.00460262643173337
# Regression Training - Epoch 1/1, Loss: 0.003910839557647705
# Regression Training - Epoch 1/1, Loss: 0.0042394367046654224
# Regression Training - Epoch 1/1, Loss: 0.0031823916360735893
# Regression Training - Epoch 1/1, Loss: 0.0037494797725230455
# Regression Training - Epoch 1/1, Loss: 0.004100840538740158
# Regression Training - Epoch 1/1, Loss: 0.003963966853916645
# Regression Training - Epoch 1/1, Loss: 0.0039151981472969055
# Regression Training - Epoch 1/1, Loss: 0.005155494436621666
# Regression Training - Epoch 1/1, Loss: 0.0037615904584527016
# Regression Training - Epoch 1/1, Loss: 0.0038204919546842575
# Regression Training - Epoch 1/1, Loss: 0.005314339883625507
# Regression Training - Epoch 1/1, Loss: 0.0046954830177128315
# Regression Training - Epoch 1/1, Loss: 0.003584792371839285
# Regression Training - Epoch 1/1, Loss: 0.004405369982123375
# Regression Training - Epoch 1/1, Loss: 0.005237405654042959
# Regression Training - Epoch 1/1, Loss: 0.004430112428963184
# Regression Training - Epoch 1/1, Loss: 0.003922334406524897
# Regression Training - Epoch 1/1, Loss: 0.004019656218588352
# Epoch11/20	  Step1/22	 Loss 0.0049	 Time 9.71
# Regression Training - Epoch 1/1, Loss: 0.0042369309812784195
# Regression Training - Epoch 1/1, Loss: 0.004264498129487038
# Regression Training - Epoch 1/1, Loss: 0.003969630226492882
# Regression Training - Epoch 1/1, Loss: 0.0034231431782245636
# Regression Training - Epoch 1/1, Loss: 0.003444251138716936
# Regression Training - Epoch 1/1, Loss: 0.004426382482051849
# Regression Training - Epoch 1/1, Loss: 0.005174889229238033
# Regression Training - Epoch 1/1, Loss: 0.003734885947778821
# Regression Training - Epoch 1/1, Loss: 0.004191795364022255
# Regression Training - Epoch 1/1, Loss: 0.0035925814881920815
# Regression Training - Epoch 1/1, Loss: 0.004238895606249571
# Regression Training - Epoch 1/1, Loss: 0.0037269608583301306
# Regression Training - Epoch 1/1, Loss: 0.0036096100229769945
# Regression Training - Epoch 1/1, Loss: 0.003994109574705362
# Regression Training - Epoch 1/1, Loss: 0.0033652340061962605
# Regression Training - Epoch 1/1, Loss: 0.004177081864327192
# Regression Training - Epoch 1/1, Loss: 0.005063377320766449
# Regression Training - Epoch 1/1, Loss: 0.004311484284698963
# Regression Training - Epoch 1/1, Loss: 0.0033096398692578077
# Regression Training - Epoch 1/1, Loss: 0.004020539112389088
# Regression Training - Epoch 1/1, Loss: 0.005711191799491644
# Regression Training - Epoch 1/1, Loss: 0.002902925480157137
# Epoch12/20	  Step1/22	 Loss 0.0161	 Time 9.71
# Regression Training - Epoch 1/1, Loss: 0.004352119751274586
# Regression Training - Epoch 1/1, Loss: 0.005026192404329777
# Regression Training - Epoch 1/1, Loss: 0.00335354870185256
# Regression Training - Epoch 1/1, Loss: 0.003968514502048492
# Regression Training - Epoch 1/1, Loss: 0.003872164525091648
# Regression Training - Epoch 1/1, Loss: 0.004269533324986696
# Regression Training - Epoch 1/1, Loss: 0.004657178185880184
# Regression Training - Epoch 1/1, Loss: 0.0046055130660533905
# Regression Training - Epoch 1/1, Loss: 0.005006520077586174
# Regression Training - Epoch 1/1, Loss: 0.0035518386866897345
# Regression Training - Epoch 1/1, Loss: 0.003743689274415374
# Regression Training - Epoch 1/1, Loss: 0.004334459081292152
# Regression Training - Epoch 1/1, Loss: 0.0031417165882885456
# Regression Training - Epoch 1/1, Loss: 0.0037402138113975525
# Regression Training - Epoch 1/1, Loss: 0.0025614616461098194
# Regression Training - Epoch 1/1, Loss: 0.004662814550101757
# Regression Training - Epoch 1/1, Loss: 0.00357079622335732
# Regression Training - Epoch 1/1, Loss: 0.0027933078818023205
# Regression Training - Epoch 1/1, Loss: 0.003315381472930312
# Regression Training - Epoch 1/1, Loss: 0.003306070575490594
# Regression Training - Epoch 1/1, Loss: 0.003918902017176151
# Regression Training - Epoch 1/1, Loss: 0.003530465066432953
# Epoch13/20	  Step1/22	 Loss 0.0060	 Time 9.70
# Regression Training - Epoch 1/1, Loss: 0.0034294086508452892
# Regression Training - Epoch 1/1, Loss: 0.003767118090763688
# Regression Training - Epoch 1/1, Loss: 0.004279476590454578
# Regression Training - Epoch 1/1, Loss: 0.004821513779461384
# Regression Training - Epoch 1/1, Loss: 0.0029702531173825264
# Regression Training - Epoch 1/1, Loss: 0.005076804663985968
# Regression Training - Epoch 1/1, Loss: 0.0041907774284482
# Regression Training - Epoch 1/1, Loss: 0.005348225124180317
# Regression Training - Epoch 1/1, Loss: 0.004515796899795532
# Regression Training - Epoch 1/1, Loss: 0.0033002670388668776
# Regression Training - Epoch 1/1, Loss: 0.004519404843449593
# Regression Training - Epoch 1/1, Loss: 0.0027644182555377483
# Regression Training - Epoch 1/1, Loss: 0.0050254445523023605
# Regression Training - Epoch 1/1, Loss: 0.0045976657420396805
# Regression Training - Epoch 1/1, Loss: 0.002782415132969618
# Regression Training - Epoch 1/1, Loss: 0.0033858814276754856
# Regression Training - Epoch 1/1, Loss: 0.003440120490267873
# Regression Training - Epoch 1/1, Loss: 0.002678531687706709
# Regression Training - Epoch 1/1, Loss: 0.004222827963531017
# Regression Training - Epoch 1/1, Loss: 0.004173668101429939
# Regression Training - Epoch 1/1, Loss: 0.0015984848141670227
# Regression Training - Epoch 1/1, Loss: 0.003825760679319501
# Epoch14/20	  Step1/22	 Loss 0.0147	 Time 9.71
# Regression Training - Epoch 1/1, Loss: 0.0038514421321451664
# Regression Training - Epoch 1/1, Loss: 0.003961354494094849
# Regression Training - Epoch 1/1, Loss: 0.0034080904442816973
# Regression Training - Epoch 1/1, Loss: 0.004432260058820248
# Regression Training - Epoch 1/1, Loss: 0.0039006343577057123
# Regression Training - Epoch 1/1, Loss: 0.0029290984384715557
# Regression Training - Epoch 1/1, Loss: 0.003353127744048834
# Regression Training - Epoch 1/1, Loss: 0.0022255401127040386
# Regression Training - Epoch 1/1, Loss: 0.0038855839520692825
# Regression Training - Epoch 1/1, Loss: 0.003544568084180355
# Regression Training - Epoch 1/1, Loss: 0.004080882295966148
# Regression Training - Epoch 1/1, Loss: 0.0042350320145487785
# Regression Training - Epoch 1/1, Loss: 0.004309468436986208
# Regression Training - Epoch 1/1, Loss: 0.0035280692391097546
# Regression Training - Epoch 1/1, Loss: 0.002452986780554056
# Regression Training - Epoch 1/1, Loss: 0.0035814663860946894
# Regression Training - Epoch 1/1, Loss: 0.004628764931112528
# Regression Training - Epoch 1/1, Loss: 0.0035463019739836454
# Regression Training - Epoch 1/1, Loss: 0.004507086239755154
# Regression Training - Epoch 1/1, Loss: 0.005169146228581667
# Regression Training - Epoch 1/1, Loss: 0.0030500851571559906
# Regression Training - Epoch 1/1, Loss: 0.003298638854175806
# Epoch15/20	  Step1/22	 Loss 0.0061	 Time 9.71
# Regression Training - Epoch 1/1, Loss: 0.004285356029868126
# Regression Training - Epoch 1/1, Loss: 0.003528805449604988
# Regression Training - Epoch 1/1, Loss: 0.003419936168938875
# Regression Training - Epoch 1/1, Loss: 0.0032840624917298555
# Regression Training - Epoch 1/1, Loss: 0.004424107261002064
# Regression Training - Epoch 1/1, Loss: 0.0029891817830502987
# Regression Training - Epoch 1/1, Loss: 0.004391844384372234
# Regression Training - Epoch 1/1, Loss: 0.0033514900133013725
# Regression Training - Epoch 1/1, Loss: 0.004081586375832558
# Regression Training - Epoch 1/1, Loss: 0.004069914110004902
# Regression Training - Epoch 1/1, Loss: 0.003767677117139101
# Regression Training - Epoch 1/1, Loss: 0.003236788557842374
# Regression Training - Epoch 1/1, Loss: 0.0035161273553967476
# Regression Training - Epoch 1/1, Loss: 0.004152687266469002
# Regression Training - Epoch 1/1, Loss: 0.0036840299144387245
# Regression Training - Epoch 1/1, Loss: 0.003890836611390114
# Regression Training - Epoch 1/1, Loss: 0.003653957974165678
# Regression Training - Epoch 1/1, Loss: 0.003740837797522545
# Regression Training - Epoch 1/1, Loss: 0.0038521429523825645
# Regression Training - Epoch 1/1, Loss: 0.003948397468775511
# Regression Training - Epoch 1/1, Loss: 0.003625313751399517
# Regression Training - Epoch 1/1, Loss: 0.0036063343286514282
# Epoch16/20	  Step1/22	 Loss 0.0056	 Time 9.72
# Regression Training - Epoch 1/1, Loss: 0.0036883894354104996
# Regression Training - Epoch 1/1, Loss: 0.004504328593611717
# Regression Training - Epoch 1/1, Loss: 0.0031066839583218098
# Regression Training - Epoch 1/1, Loss: 0.003372079459950328
# Regression Training - Epoch 1/1, Loss: 0.0038513196632266045
# Regression Training - Epoch 1/1, Loss: 0.003456677542999387
# Regression Training - Epoch 1/1, Loss: 0.0032201269641518593
# Regression Training - Epoch 1/1, Loss: 0.004336530342698097
# Regression Training - Epoch 1/1, Loss: 0.004600126296281815
# Regression Training - Epoch 1/1, Loss: 0.004270412027835846
# Regression Training - Epoch 1/1, Loss: 0.003118174849078059
# Regression Training - Epoch 1/1, Loss: 0.003952714614570141
# Regression Training - Epoch 1/1, Loss: 0.004142132122069597
# Regression Training - Epoch 1/1, Loss: 0.004182667471468449
# Regression Training - Epoch 1/1, Loss: 0.003758086822926998
# Regression Training - Epoch 1/1, Loss: 0.0041115377098321915
# Regression Training - Epoch 1/1, Loss: 0.0031256629154086113
# Regression Training - Epoch 1/1, Loss: 0.004338739439845085
# Regression Training - Epoch 1/1, Loss: 0.0033557775896042585
# Regression Training - Epoch 1/1, Loss: 0.0036782482638955116
# Regression Training - Epoch 1/1, Loss: 0.002896450459957123
# Regression Training - Epoch 1/1, Loss: 0.0036936956457793713
# Epoch17/20	  Step1/22	 Loss 0.0034	 Time 9.70
# Regression Training - Epoch 1/1, Loss: 0.005467668641358614
# Regression Training - Epoch 1/1, Loss: 0.0039346469566226006
# Regression Training - Epoch 1/1, Loss: 0.0037434115074574947
# Regression Training - Epoch 1/1, Loss: 0.004395331721752882
# Regression Training - Epoch 1/1, Loss: 0.00393759785220027
# Regression Training - Epoch 1/1, Loss: 0.003906372468918562
# Regression Training - Epoch 1/1, Loss: 0.004048620350658894
# Regression Training - Epoch 1/1, Loss: 0.0037844234611839056
# Regression Training - Epoch 1/1, Loss: 0.0037028081715106964
# Regression Training - Epoch 1/1, Loss: 0.004365510307252407
# Regression Training - Epoch 1/1, Loss: 0.0033282418735325336
# Regression Training - Epoch 1/1, Loss: 0.0032840119674801826
# Regression Training - Epoch 1/1, Loss: 0.003574273781850934
# Regression Training - Epoch 1/1, Loss: 0.004118972457945347
# Regression Training - Epoch 1/1, Loss: 0.0033527626655995846
# Regression Training - Epoch 1/1, Loss: 0.0036997483111917973
# Regression Training - Epoch 1/1, Loss: 0.0035474130418151617
# Regression Training - Epoch 1/1, Loss: 0.0032230063807219267
# Regression Training - Epoch 1/1, Loss: 0.004482069052755833
# Regression Training - Epoch 1/1, Loss: 0.003941508941352367
# Regression Training - Epoch 1/1, Loss: 0.002268601907417178
# Regression Training - Epoch 1/1, Loss: 0.004396411590278149
# Epoch18/20	  Step1/22	 Loss 0.0051	 Time 9.71
# Regression Training - Epoch 1/1, Loss: 0.0033828048035502434
# Regression Training - Epoch 1/1, Loss: 0.003410098608583212
# Regression Training - Epoch 1/1, Loss: 0.0026197643019258976
# Regression Training - Epoch 1/1, Loss: 0.005027693696320057
# Regression Training - Epoch 1/1, Loss: 0.0030051206704229116
# Regression Training - Epoch 1/1, Loss: 0.0035543455742299557
# Regression Training - Epoch 1/1, Loss: 0.003672179067507386
# Regression Training - Epoch 1/1, Loss: 0.0032239453867077827
# Regression Training - Epoch 1/1, Loss: 0.004328540526330471
# Regression Training - Epoch 1/1, Loss: 0.0034214062616229057
# Regression Training - Epoch 1/1, Loss: 0.003570780623704195
# Regression Training - Epoch 1/1, Loss: 0.004081099759787321
# Regression Training - Epoch 1/1, Loss: 0.003603363409638405
# Regression Training - Epoch 1/1, Loss: 0.003667078912258148
# Regression Training - Epoch 1/1, Loss: 0.0038416734896600246
# Regression Training - Epoch 1/1, Loss: 0.003470923751592636
# Regression Training - Epoch 1/1, Loss: 0.002954206895083189
# Regression Training - Epoch 1/1, Loss: 0.0047458987683057785
# Regression Training - Epoch 1/1, Loss: 0.0037154394667595625
# Regression Training - Epoch 1/1, Loss: 0.0037381178699433804
# Regression Training - Epoch 1/1, Loss: 0.005286581814289093
# Regression Training - Epoch 1/1, Loss: 0.005170921795070171
# Epoch19/20	  Step1/22	 Loss 0.0103	 Time 9.71
# Regression Training - Epoch 1/1, Loss: 0.00416234927251935
# Regression Training - Epoch 1/1, Loss: 0.002938993740826845
# Regression Training - Epoch 1/1, Loss: 0.00504434434697032
# Regression Training - Epoch 1/1, Loss: 0.0033660498447716236
# Regression Training - Epoch 1/1, Loss: 0.003950301557779312
# Regression Training - Epoch 1/1, Loss: 0.003781033679842949
# Regression Training - Epoch 1/1, Loss: 0.003206830471754074
# Regression Training - Epoch 1/1, Loss: 0.003698569955304265
# Regression Training - Epoch 1/1, Loss: 0.0036195823922753334
# Regression Training - Epoch 1/1, Loss: 0.0039603025652468204
# Regression Training - Epoch 1/1, Loss: 0.00352411437779665
# Regression Training - Epoch 1/1, Loss: 0.0027479541022330523
# Regression Training - Epoch 1/1, Loss: 0.0038809743709862232
# Regression Training - Epoch 1/1, Loss: 0.003050990868359804
# Regression Training - Epoch 1/1, Loss: 0.0026219459250569344
# Regression Training - Epoch 1/1, Loss: 0.0030838283710181713
# Regression Training - Epoch 1/1, Loss: 0.007173985242843628
# Regression Training - Epoch 1/1, Loss: 0.0021737138740718365
# Regression Training - Epoch 1/1, Loss: 0.002753067295998335
# Regression Training - Epoch 1/1, Loss: 0.0038127549923956394
# Regression Training - Epoch 1/1, Loss: 0.003651505336165428
# Regression Training - Epoch 1/1, Loss: 0.003289904911071062
# Epoch20/20	  Step1/22	 Loss 0.0066	 Time 9.71
# Regression Training - Epoch 1/1, Loss: 0.0036889587063342333
# Regression Training - Epoch 1/1, Loss: 0.005184153560549021
# Regression Training - Epoch 1/1, Loss: 0.002911810763180256
# Regression Training - Epoch 1/1, Loss: 0.003840372199192643
# Regression Training - Epoch 1/1, Loss: 0.003709600307047367
# Regression Training - Epoch 1/1, Loss: 0.0039842696860432625
# Regression Training - Epoch 1/1, Loss: 0.0035184710286557674
# Regression Training - Epoch 1/1, Loss: 0.0044021643698215485
# Regression Training - Epoch 1/1, Loss: 0.004217210691422224
# Regression Training - Epoch 1/1, Loss: 0.004299012478441
# Regression Training - Epoch 1/1, Loss: 0.0049094948917627335
# Regression Training - Epoch 1/1, Loss: 0.0031936634331941605
# Regression Training - Epoch 1/1, Loss: 0.002906255889683962
# Regression Training - Epoch 1/1, Loss: 0.0036624472122639418
# Regression Training - Epoch 1/1, Loss: 0.0026410557329654694
# Regression Training - Epoch 1/1, Loss: 0.004105068743228912
# Regression Training - Epoch 1/1, Loss: 0.0030666321981698275
# Regression Training - Epoch 1/1, Loss: 0.003932332620024681
# Regression Training - Epoch 1/1, Loss: 0.0030229566618800163
# Regression Training - Epoch 1/1, Loss: 0.002843781840056181
# Regression Training - Epoch 1/1, Loss: 0.002104602288454771

# %%
data_iter = iter(test_loader)
input_img, cond_img, reg_params = next(data_iter)

# Ensure images are on the correct device and of type float32
input_img = input_img.to(device).float()
cond_img = cond_img.to(device).float()

# Define the image size and channels (modify as per your requirements)
image_size = input_img.shape[-1]
channels = input_img.shape[1]

# Call the sample method
generated_images = gaussian_diffusion.sample(
    model=diff_model,
    image_size=image_size,
    cond_img=cond_img,
    batch_size=32,  # Set the desired batch size
    channels=channels,
    w=2,
    clip_denoised=True
)

grid_size = int(np.ceil(np.sqrt(generated_images[-1].shape[0])))

# Plot the images
fig, axes = plt.subplots(grid_size, grid_size, figsize=(10, 10))

# Remove axis for each subplot
for ax in axes.flatten():
    ax.axis('off')

# Plot each image
for i, ax in enumerate(axes.flatten()):
    if i < generated_images[-1].shape[0]:
        ax.imshow(generated_images[-1][i].transpose(1, 2, 0), cmap='gray')

plt.tight_layout()
plt.show()
# Out:
# sampling loop time step: 100%|████████████████████████████████████████████████████████| 500/500 [02:35<00:00,  3.22it/s]

# %%
# MODEL_SAVE_PATH = os.path.join(VOL_DIR, 'results/ckpts/gde_ensemble_model_4_64x64_simData_regGuided.h5')
# torch.save(diff_model, MODEL_SAVE_PATH)
